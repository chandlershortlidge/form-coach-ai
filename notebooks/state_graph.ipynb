# %%
from langgraph.graph import StateGraph
from typing import TypedDict
import os 
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from chat_memory import get_chat_history
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.messages import HumanMessage
from video_processing import analyze_video
from vectorstore_setup import clean_classification_text
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langgraph.graph import StateGraph, START, END
import tempfile

embeddings = OpenAIEmbeddings(model='text-embedding-3-small')
vectorstore = Chroma(persist_directory="/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/chroma_db", embedding_function=embeddings)

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGSMITH_API_KEY")


# Whisper speach to text 
from openai import OpenAI
client = OpenAI()

# %%
query_router = ChatPromptTemplate.from_messages([
    ("system", """Your job is to classify user queries into two buckets: 
     - memory
     - memory and vectorstore
     
     *Guidelines*
     Questions regarding exercises, exercise form, or technique: vectorstore & memory
     General question or statements: memory
   
     *Respond to queries with only the correct class*
     Examples: 
     User: how should I grip the bar for bench press?
     Agent: vectorstore & memory

     User: what muscles should I feel during the Romanian dead lift?
     Agent: vectorstore & memory

     User: How's this? 
     Agent: vectorstore & memory

     User: Is this good squat technique? 
     Agent: vectorstore & memory

     User: Was my bar path better?
     Agent: vectorstore & memory

     User: thakns for your help!
     Agent: memory

"""),

     ("human", "{query}")
     
])

llm = ChatOpenAI(model='gpt-4o-mini')

output_parser = StrOutputParser()

router_chain = query_router | llm | output_parser

# %%
# Define the state

# the state is a dictionary

class GraphState(TypedDict):

    session_id: int 

    user_query: str

    user_video: str

    classification_image: str

    classified_keywords: str

    top_k_chunks: str

    encoded_images: list[str]

    response: str

# %% [markdown]
# # Router function: conditional edge

# %%
def route_query(state: GraphState):
    # first check: is there a video?
    if state["user_video"]:
        return "video_encoder"
    
    # no video — ask the router_prompt LLM which path
    route = router_chain.invoke({"query": state["user_query"]})
    route = route.lower().strip()
    
    if "vectorstore" in route:
        return "vector_db"
    else:
        return "chat_memory"

# %% [markdown]
# # Video Encoder Node

# %%
def video_encoder_node(state: GraphState):
    user_video = state["user_video"]
    user_video_encoded = analyze_video(filepath_in=user_video, frame_count=15, max_seconds=10) # encodes video
    encoded_images = [] # creates a list of encoded images for LLM
    for images in user_video_encoded:
        encoded_images.append({"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{images}"}})
        classification_image = user_video_encoded[0] 
    
    return {"classification_image": classification_image, "encoded_images": encoded_images}

# %% [markdown]
# # Video Classification Node

# %%
# video classification router NODE

def video_classification_node(state: GraphState):
    classification_image = state["classification_image"]

    router_llm = ChatOpenAI(model='gpt-4o')

    response = router_llm.invoke([

    {"role": "user", "content": 

    [{"type": "text", "text":  """Your job is to analyze images of users working out for proper form, and list the key checkpoints of their to body evaluate. 
    Give me ONLY the bodypart checkpoints. Do NOT include evaluation suggestions. Do NOT include an intro sentence. 
    Output format should be exactly the example below.
    **Example**
    Overhead press

    1. Feet & base
    2. Glutes & legs
    3. Core & Ribcage
    4. Shoulder position
    5. Bar path
    6. Head & Neck
    7. Lockout position
    8. Tempo and control
    """},


        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{classification_image}"}}
        ]}


    ])

    classified_keywords = clean_classification_text(response)

    return {"classified_keywords": classified_keywords}

# %% [markdown]
# # VectorDB Node

# %%
def vector_db_node(state: GraphState):
    user_query = state["user_query"]
    classified_keywords = state.get("classified_keywords", "")
    retrieval_query = classified_keywords

    if classified_keywords:
        results_user = vectorstore.similarity_search(user_query, k=5)
        results_video = vectorstore.similarity_search(retrieval_query, k=5)
        results = results_user + results_video

    if not classified_keywords: 
        results_user = vectorstore.similarity_search(user_query, k=5)
        results = results_user

    unique_results = []
    seen = set()

    for r in results:
        content = r.page_content
        if content not in seen:
            seen.add(content)
            unique_results.append(r)


    top_k_chunks = "\n".join([r.page_content for r in unique_results])

    print(f"RESULTS COUNT: {len(results)}")
    print(f"UNIQUE RESULTS COUNT: {len(unique_results)}")
    for r in unique_results[:2]:
        print(f"CHUNK PREVIEW: {r.page_content[:100]}")

    return {"top_k_chunks": top_k_chunks}

# %% [markdown]
# # Response Generator Node

# %%
def response_generator(state: GraphState):
    top_k_chunks = state['top_k_chunks']
    encoded_images = state.get("encoded_images", [])
    session_id = state["session_id"]
    user_query = state["user_query"]
    classified_keywords = state["classified_keywords"]

    prompt = ChatPromptTemplate.from_messages([
            ("system", """You are a world-class fitness coach. You have extensive experience in helping weight lifters achieve perfect form and maximum hypertrophy. 
    Your job is to analyze images of users lifting weights, offer them advice from your context, and to answer any questions they might have. 
    Inspect each image CLOSELY and carefully. Look for issues realted to form, safety, and unhelpful camera angles.
    Be specific about what you observe and include that in your feedback.
             
    # BEHAVIOR INSTRUCTIONS
    1. Tone
    - You're eager and excited to help 
   2. How to analyze
    - Break down your analysis into three sections
        What looks good
             - 1 to 2 points
        Main fixes
             - Cover all significant issues you observe
        Mental cues
             - A brief list of mental cues the lifter can easily remember during their lift


    # ANSWER CONTEXT
    First describe what you observe in the images.         
    Then use the ONLY following context to provide coaching advice:
 
    {top_k_chunks}
    
    If the query or image isn't in context, reply, 'I don't have expert coaching advice for this exercise yet. 
    Currently I can analyze: bench press, overhead press, incline bench press...'"
        
    ---  


    """),
        MessagesPlaceholder(variable_name="history"),
        MessagesPlaceholder(variable_name="input"),
    ])



    user_msg = HumanMessage(content=[
        {"type": "text", "text": user_query},
        *encoded_images,   # <- your list of {"type":"image_url",...}
    ])

    llm = ChatOpenAI(model='gpt-5',
                    temperature=0.5)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser

    chain_with_history = RunnableWithMessageHistory(
        chain,
        get_session_history=get_chat_history,
        input_messages_key="input",
        history_messages_key="history"

    )

    response = chain_with_history.invoke(
        {"input": [user_msg], "top_k_chunks": top_k_chunks, "classified_keywords": classified_keywords},
        config={"configurable": {"session_id": session_id}}
    )


    return {"response": response}

# %% [markdown]
# # Chat Memory node

# %%
def chat_memory(state: GraphState):
    user_query = state["user_query"]
    session_id = state["session_id"]
    
    prompt = ChatPromptTemplate.from_messages([
            ("system", """You are a world-class fitness coach. You have extensive experience in helping weight lifters achieve perfect form and maximum hypertrophy. 
    Your job is to analyze images of users lifting weights, offer them advice from your context, and to answer any questions they might have. 


    """),
        MessagesPlaceholder(variable_name="history"),
        MessagesPlaceholder(variable_name="input"),
    ])

    user_msg = HumanMessage(content=[
        {"type": "text", "text": user_query}
    ])

    llm = ChatOpenAI(model='gpt-4o',
                    temperature=0.5)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser

    chain_with_history = RunnableWithMessageHistory(
        chain,
        get_session_history=get_chat_history,
        input_messages_key="input",
        history_messages_key="history"

    )

    response = chain_with_history.invoke(
        {"input": [user_msg]},
        config={"configurable": {"session_id": session_id}}
    )

    return {"response": response}

# %% [markdown]
# # Audio transcription function

# %%
# def transcribe_audio(audio_path):
#     audio_file = open(audio_path, "rb") # rb = read binary. audio files are binary data (raw bytes). this tells python gto open as binary instaed of text
#     transcription = client.audio.transcriptions.create(
#         model="whisper-1",
#         file=audio_file
#     )
# def transcribe_audio(audio_path):
#     audio_file = open(audio_path, "rb") # rb = read binary. audio files are binary data (raw bytes). this tells python gto open as binary instaed of text
#     transcription = client.audio.transcriptions.create(
#         model="whisper-1",
#         file=audio_file
#     )

#     return transcription.text
    

# user_query = transcribe_audio("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/raw_voice_notes/bench_press_voice_note.m4a")
# print(user_query)

# %%
# rebuild graph fresh each time this cell runs
workflow = StateGraph(GraphState)

# conditional edge
workflow.add_conditional_edges(START, route_query)

# add nodes
workflow.add_node("video_encoder", video_encoder_node)
workflow.add_node("video_classification_router", video_classification_node)
workflow.add_node("vector_db", vector_db_node)
workflow.add_node("response_generator", response_generator)
workflow.add_node("chat_memory", chat_memory)



# connect them
workflow.add_edge("chat_memory", END)
workflow.add_edge("video_encoder", "video_classification_router")
workflow.add_edge("video_classification_router", "vector_db")
workflow.add_edge("vector_db", "response_generator")
workflow.add_edge("response_generator", END)

app = workflow.compile()

# %%
result = app.invoke({
    "session_id": 234,
    "user_query": "how's my form?",
    "user_video": "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/raw_workout_videos/bench_press/bench_20.MP4"
})

print(result["response"])
# Out:
# Frames processed: 15, (10s cap)
# Saved to processed-images/bench_20
# Video name: bench_20
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# Here’s what I see
# - You’re benching in a rack with a noticeable chest arch and you’re touching the bar to your chest each rep.
# - Your grip looks a bit on the narrow side and your feet appear to be up on the bench or off the floor, which limits leg drive.
#
# What looks good
# - You’re consistently bringing the bar to the chest instead of hovering.
# - You have a solid upper‑body arch that helps present the chest high.
#
# Main fixes
# - Plant your feet: set your feet as far back as you comfortably can with shins nearly vertical, heels flat on the floor, and legs close to the bench when viewed from the front. Drive through your heels to reinforce the arch, but keep your hips down so your butt stays on the bench.
# - Lock in the setup: eyes directly under the bar before the unrack; maintain four points of contact—head, upper back, glutes, and feet all planted.
# - Upper‑back tension: pinch the shoulder blades together to make a firm platform and grip the bar as hard as you can (think “bend the bar” to stay tight).
# - Bar path and elbow angle: on the descent, let the elbows track about 45 degrees from your torso; on the press, throw the bar slightly back toward the rack so it follows an upside‑down J, not straight up in front of you.
# - Eye focus: pick one spot on the ceiling and don’t let your eyes move. Lower to the same touchpoint and drive back to that fixed spot each rep.
# - Grip width: you may be stronger with a slightly wider grip—experiment to find your strongest position.
#
# Mental cues
# - Heels down, knees out a touch; butt stays on the bench.
# - Chest up, shoulder blades pinched.
# - Huge breath into the gut, brace hard.
# - Squeeze the bar; “rip it in half.”
# - Touch and go to the same spot; “throw it back” on the press.
#
# Programming note
# - For your next sets of five, add a little weight until bar speed slows and form starts to change. Stay there for two more sets of five. For goals: generally 5–10 reps for hypertrophy, 3–6 for strength.
#
# Camera tweak
# - Next time, include a side angle that shows your feet and hips so I can confirm heels planted and butt contact throughout.
#
# If you’re pushing near max, I prefer having a spotter help with the liftoff.

# %%
# result = app.invoke({
#     "session_id": 123,
#     "user_query": user_query,
#     "user_video": ""
# })

# print(result["response"])

# %%
# result = app.invoke({
#     "session_id": 123,
#     "user_query": "thanks for your help today!",
#     "user_video": ""
# })
# result = app.invoke({
#     "session_id": 123,
#     "user_query": "thanks for your help today!",
#     "user_video": ""
# })

# print(result["response"])

# %%
# result = app.invoke({
#     "session_id": 123,
#     "user_query": "can you tell me again how to make it easier?",
#     "user_video": ""
# })

# print(result["response"])

# %%
def correctness_evaluator(run, example):
    generated = run.outputs["answer"]
    reference = example.outputs["answer"]
    question = example.inputs["user_query"]

    prompt = f"""You are evaluating a fitness coaching AI assistant.
Your job is to assess the quality of its response against a reference answer. 
The reference answer contains the minimum key observations. The generated answer may expand on these with additional coaching advice and this should not be penalized.

Question: {question}
Reference answer: {reference}
Generated answer: {generated}

Scoring criteria:

Score 0 — The generated answer contains incorrect or potentially harmful advice that contradicts the reference answer. This is the worst outcome.
Score 1 — The generated answer is incomplete or omits important details from the reference, but contains nothing incorrect or harmful.
Score 2 — The generated answer is correct and captures the key facts from the reference answer.

Important: Penalize incorrect advice more harshly than omission. A response that says nothing is better than one that says something wrong.

Reply with only the number: 0, 1, or 2."""

    from openai import OpenAI
    openai_client = OpenAI()
    result = openai_client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt}]
    )
    try: 
        score_raw = result.choices[0].message.content.strip()
        score = int(''.join(filter(str.isdigit, score_raw))[0])
    except Exception as e:
        print(f"Error parsing score: {e}, raw output: {score_raw}")
        score = -1
    return {"key": "correctness", "score": score / 2} # normalize the score for LangSmith configurations

# %%
def hallucination_evaluator(run, example):
    generated = run.outputs["answer"]
    context = run.outputs["context"]
    
    prompt = f"""YYou are evaluating a fitness coaching AI assistant for hallucinations.

This AI analyzes workout VIDEOS and uses retrieved coaching context to provide form advice. 
The AI has two information sources:
1. Retrieved text context (coaching knowledge)
2. Video frames of the user's actual lift (visual observations)

<Instructions>
  - Claims about coaching best practices (e.g. "elbows should be 45-60 degrees") should be verified against the retrieved context
  - Claims about what the user is DOING in their video (e.g. "your elbows are flaring wide") are visual observations and should NOT be penalized for not appearing in the retrieved context
  - Only flag a claim as hallucinated if it contradicts the retrieved context or makes up coaching advice not supported by the context
  - Observations about the user's form that are plausible given a workout video should be treated as valid even if not in the context
</Instructions>

Retrieved context:
{context}

Generated answer:
{generated}

Scoring criteria:

Score 0 — The answer contains coaching advice that directly contradicts the retrieved context, or invents training recommendations with no basis in the context. This is the worst outcome.
Score 1 — The coaching advice is mostly supported by the context but includes minor unsupported recommendations.
Score 2 — All coaching advice and recommendations are directly supported by the retrieved context. Visual observations about the user's form do not count against this score.

Reply with only the number: 0, 1, or 2."""

    from openai import OpenAI
    openai_client = OpenAI()
    result = openai_client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt}]
    )
    try:
        score_raw = result.choices[0].message.content.strip()
        score = int(''.join(filter(str.isdigit, score_raw))[0])
    except:
        score = None
    return {"key": "hallucination", "score": score / 2} # normalize the score

# %%
from uuid import uuid4

def run_rag_pipeline(inputs: dict, attachments: dict) -> dict:
    # grab video from attachments in LangSmith
    video_name = list(attachments.keys())[0] 
    # read the video as raw bytes
    video_bytes = attachments[video_name]["reader"].read()
    
    # save to temp file because analyze_video expects a filepath
    with tempfile.NamedTemporaryFile(suffix=".mp4", delete=False) as tmp:
        # . delete=False means "don't delete this file when we're done writing" because we still need it for the pipeline.
        tmp.write(video_bytes)
        tmp_path = tmp.name
    
    state = {
        "user_query": inputs["user_query"],
        "session_id": f"eval-{uuid4()}",
        "classified_keywords": "",
        "encoded_images": [],
        "user_video": tmp_path
    }
    
    state = {**state, **video_encoder_node(state)}
    state = {**state, **video_classification_node(state)}
    print(f"BEFORE VECTOR DB - classified_keywords: {state.get('classified_keywords', 'MISSING')}")
    state = {**state, **vector_db_node(state)}
    print(f"AFTER VECTOR DB - top_k_chunks length: {len(state.get('top_k_chunks', ''))}")
    state = {**state, **response_generator(state)}

    print("STATE KEYS:", state.keys())
    print("RESPONSE:", state.get("response", "NOT FOUND"))
    
    return {"answer": state["response"],
            "context": state["top_k_chunks"]}

# %%
from langsmith import Client
from langsmith.evaluation import evaluate

langsmith_client = Client()

os.environ["LANGCHAIN_TRACING_V2"] = "false" 
# stops LangSmith from trying to log all the big intermediate data
# evaluate() function will still capture your inputs, outputs, and evaluator scores
# it just won't try to upload the full trace with all those heavy frames.

results = evaluate(
    run_rag_pipeline,
    data="Image assessment response accuracy v1",
    evaluators=[correctness_evaluator, hallucination_evaluator],
    experiment_prefix="vision-faithfulness-rag-updated-system-prompt-test3"
)
# Out:
# View the evaluation results for experiment: 'vision-faithfulness-rag-updated-system-prompt-test3-fda65fe2' at:
# https://smith.langchain.com/o/5dffb1fc-82e5-4000-a9a5-d9c923e0f73c/datasets/1be4093e-6f7d-4021-a94b-d6cf76c22b6a/compare?selectedSessions=32bd4fe2-097e-4af2-b369-27dcf43358a4
# 0it [00:00, ?it/s]
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmprs6rl274
# Video name: tmprs6rl274
# BEFORE VECTOR DB - classified_keywords:   Dumbbell Bench Press       Feet   base    Glutes   legs    Core   Ribcage    Shoulder position    Elbow alignment    Dumbbell path    Head   Neck    Grip and wrist position
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9283
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: What I see:
# - Flat dumbbell bench press with alternating reps.
# - Your butt and head stay on the bench, but your feet are wide and up on the toes at times, with heels floating.
# - Elbows flare fairly wide on the way down; the dumbbells land around chest level.
# - Upper back/chest doesn’t look maximally “set” on the pad; your gaze shifts with the bells.
#
# What looks good
# - Controlled reps without bouncing the dumbbells off the chest.
# - Butt stays down on the bench throughout.
#
# Main fixes
# - Plant your feet and use leg drive: get each foot back as far as you comfortably can with the heels flat on the floor. Keep the legs closer to the bench when viewed from the front, shins nearly vertical, and keep the hips down so the butt stays in contact with the pad. Avoid “floppy feet.”
# - Set your upper back as a base: pinch the shoulder blades together and keep the upper back planted firmly on the bench to keep the chest high and reinforce your arch.
# - Elbow path: lower with the elbows about 45 degrees relative to your torso rather than flared out. Touch the chest lightly, then press.
# - Brace each rep: take a huge breath into your diaphragm, press the air out against your belt if you use one, squeeze the glutes, and keep your weight balanced through each foot.
# - Lock your eyes on a fixed point on the ceiling so every rep tracks to the same spot.
# - If form changes or the feet start to move, add a little less weight and work sets of five until bar speed (dumbbell speed here) begins to slow but form stays locked in.
#
# Mental cues
# - Heels down, feet tucked back, legs tight.
# - Pinch shoulder blades to the bench; chest up.
# - Big belly breath, brace hard.
# - Elbows 45°, touch, then drive.
# - Eyes fixed on one ceiling spot.
#
# Camera note: Next time, add a side view and a front view so I can verify elbow angle and heel contact more clearly.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmp1jxtvkwr
# Video name: tmp1jxtvkwr
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Back   arch    Core   Ribcage    Shoulder position    Grip   Wrist alignment    Elbow position    Bar path    Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8080
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Thanks for the clips—love the effort here.
#
# What I see
# - Flat bench press in a rack. You’re using a noticeable arch with your head and upper back on the bench and locking out each rep.
# - On the way down, the bar travels very high toward your upper chest/neck, and your elbows flare a lot. Your wrists look bent back behind the bar. I can’t clearly see your feet or heels from this angle.
#
# What looks good
# - You keep a consistent arch and stay in control through the set.
# - You’re finishing reps with straight elbows and not bouncing.
#
# Main fixes
# - Touch point and elbow angle: Lower the bar to your chest, but aim for the lower chest/upper sternum with your elbows around 45 degrees to your torso, not flared out. Think about bending the bar into a U as you descend—this naturally tucks the elbows and engages the lats.
# - Bar path and eye focus: Trap a spot on the ceiling with your eyes, unlock your elbows, touch the chest without pausing, then drive the bar back to that fixed ceiling point every rep.
# - Wrist and grip: Grip the bar as hard as you can and keep your wrists stacked over your forearms. If your forearms aren’t vertical at the chest, adjust your grip width so they are. Use a full, tight grip and “rip the bar in half” to stay tight.
# - Upper-back platform: Before unracking, adduct (pinch) your shoulder blades and plant your upper back firmly into the bench to create a stable base to press from.
# - Legs and butt (can’t see them—adjust if needed): Set your feet as far back as comfortable with your legs close to the bench when viewed from the front. Keep your heels flat on the floor with shins nearly vertical to use leg drive, and make sure your hips stay down so your butt touches the bench the whole time. Avoid “floppy feet.”
# - Unrack and bracing: Set up with eyes directly under the bar, take a deep breath into your gut to brace, then lift the bar out (not up). Ensure four points of contact the whole set: head, upper back, glutes, and feet.
# - Programming note: For your work sets, add a little weight until bar speed slows and form starts to change. Stay at that weight for two more sets of five.
#
# Mental cues
# - Pinch shoulder blades; puff chest up.
# - Huge belly breath, brace hard.
# - Bend the bar; protect your armpits.
# - Tuck to ~45°, touch lower chest, press back to your ceiling spot.
# - Heels down, knees out, butt down.
# - Squeeze the bar and don’t let your feet move.
#
# Camera tip: Next time, include your lower body in frame (side or 45° angle) so I can confirm heel contact, shin angle, and that your butt stays down.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpfv7pajph
# Video name: tmpfv7pajph
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Glutes   legs    Core   Ribcage    Shoulder position    Grip   Wrist alignment    Elbow position    Bar path    Head   Neck    Lockout position     Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8235
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: What I’m seeing
# - Flat bench inside a rack, wide grip, solid arch. You’re touching the bar to your chest and pressing to lockout.
# - Feet are splayed wide and move during reps; heels pop up and you look up on your toes. Your shins are angled and not close to vertical.
# - Glutes look like they’re starting to float as you drive, and elbows appear slightly flared on the way down.
# - Camera is front/diagonal, so bar path and touch point are a bit hard to verify.
#
# What looks good
# - Strong upper‑back arch and wide grip, which can be a powerful setup.
# - You’re controlling the descent and touching the chest rather than hovering.
#
# Main fixes
# - Foot position and leg drive
#   - Set your feet as far back as you comfortably can but keep them close to the bench when viewed from the front. Aim for shins nearly vertical.
#   - Plant the heels flat on the floor. Heels down lets you drive up the legs more efficiently than being on your toes and helps stop the hips from bridging.
#   - Avoid “floppy feet.” Pick your spots and keep them glued for the whole set.
# - Keep four points of contact
#   - Head, upper back, glutes, and feet all planted. Make sure your hips stay down so your butt touches the bench at all times.
#   - Pinch the shoulder blades together and use the upper back as your platform.
# - Elbow path and bar path
#   - On the way down, drop the elbows to about a 45-degree angle relative to your torso.
#   - Fix your eyes on a point on the ceiling, touch the bar to your chest, then drive it back toward that ceiling point in a slight upside‑down J.
# - Unrack and brace
#   - Set up with your eyes directly under the bar. Use a spotter to lift out (or briefly elevate hips for liftoff, then drop them), take a huge breath into your gut, and grip the bar as hard as you can—think “bend the bar” to lock in your upper back.
# - Loading
#   - Use sets of five and add a little weight until bar speed slows or form changes, then stay there for two more sets of five. If form slips, take some weight off and rebuild with tight feet and hips.
#
# Mental cues
# - Eyes under the bar, squeeze shoulder blades.
# - Heels down, feet in tight, shins near vertical.
# - Butt on bench—no bridge.
# - Big breath and brace, crush the bar.
# - Elbows ~45 degrees, touch and throw it back to your ceiling target.
#
# If you can, a side view at bench height will let me check your exact touch point and bar path more precisely. And if this is near a max, I prefer having a spotter for the liftoff.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpx_xoljg2
# Video name: tmpx_xoljg2
# BEFORE VECTOR DB - classified_keywords: Bench Press     Feet   base    Glutes   legs    Core   lower back    Shoulder position    Elbow alignment    Bar path    Wrist   grip    Head   Neck
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8284
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s what I see in your bench video:
# - You touch the bar to your chest each rep and lock out under control. Your butt stays on the bench the whole time.
# - Your feet look mostly stable, but they’re set a bit forward. Your elbows flare pretty wide, and the bar is touching high on your chest (closer to the clavicles) and then traveling forward.
#
# What looks good
# - Full range of motion with a controlled descent and no bouncing.
# - Glutes stay down on the pad.
#
# Main fixes
# 1) Nail the setup before unrack
# - Slide yourself so your eyes are directly under the bar. Unrack by lifting the bar out, not up. Keep your shoulder blades pinched together and your upper back planted as your platform. Keep four points of contact: head, upper back, glutes, and feet.
#
# 2) Foot position and leg drive
# - Tuck your feet farther back so your shins are nearly vertical when viewed from the side. Keep heels flat on the floor (externally rotate or toe out slightly if needed) and use the heels as your base to reinforce your arch. Drive through the heels while keeping your hips down.
#
# 3) Bar path and elbow angle
# - On the descent, drop your elbows to about 45 degrees relative to your torso (they’re flaring too much now). Lower the bar to the lower chest/sternum, touch without stopping, then press back toward the point on the ceiling your eyes are fixed on. This keeps a consistent path and shoulders happier.
#
# 4) Grip and tightness
# - Grip the bar as hard as you can; think “bend the bar” to keep the upper back tight. You may find a slightly wider grip stronger—experiment with a small increase in width while keeping the 45-degree elbow angle.
#
# 5) Loading guidance
# - Do sets of five with the bar to groove the eye-focus and bar path, then add a little weight until bar speed starts to slow and your form wants to change. Stay there for two more sets of five for your first work set.
#
# Mental cues
# - Eyes trap a spot on the ceiling; bar returns to that spot.
# - Heels glued; shins vertical; legs tight.
# - Pinch shoulder blades; chest high; arch set.
# - Bend the bar; elbows ~45°.
# - Touch sternum; drive back to eyes.
#
# Camera note
# - Next time, film from the side at bench height and from the front to clearly see bar path, elbow angle, and shin position.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmp2qijyqp9
# Video name: tmp2qijyqp9
# BEFORE VECTOR DB - classified_keywords: Bench Press     Feet   base    Glutes   legs    Core   Ribcage    Shoulder position    Bar path    Hand   wrist position    Head   Neck    Lockout position    Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9204
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s what I see
# - Flat barbell bench in a fixed rack. You touch the bar to your chest on each rep and press to lockout. Tempo is steady with a quick touch-and-go.
# - Your upper back looks set and you keep a small arch.
# - On the harder reps your hips bridge up and your butt appears to come off the pad. Your feet also look like they shift/rock a bit, especially the left heel.
# - Side-on camera angle makes it hard to judge eye position under the bar and true elbow angle/bar path.
#
# What looks good
# - Consistent touch to the chest and full lockouts.
# - Upper back looks engaged; you’re keeping some arch and staying tight up top.
#
# Main fixes
# - Keep four points of contact the whole set: head, upper back, glutes, and feet. Don’t let your butt come off the bench at any time.
# - Reset your lower body for real leg drive:
#   - Plant your heels flat on the floor.
#   - Pull your feet back so your shins are nearly vertical and keep your legs in close to the bench when viewed from the front.
#   - Externally rotate or point toes out slightly if needed to keep heels down.
#   - Use the drive from your heels to reinforce your arch and keep the chest high—don’t let that leg drive turn into a hip bridge.
# - Setup details to tighten everything:
#   - Lie back with your eyes directly under the bar.
#   - Pinch your shoulder blades together and down to make a firm upper‑back platform.
#   - Grip the bar hard; think about bending/ripping the bar to activate your upper back.
# - Unrack and execution:
#   - If unracking alone, you can lift your butt slightly only for the liftoff, then drop your hips before you start the first rep; better yet, get a spotter for heavy sets to help you lift out, not up.
#   - During the descent, keep elbows about 45° to your torso, touch the chest without stopping, then drive the bar back in an upside‑down J toward the rack.
#   - Fix your gaze on a single point on the ceiling so the bar returns to the same spot every rep.
#   - After the last rep, move the bar back to the rack with locked elbows.
#
# Mental cues
# - Heels down, shins vertical, butt glued.
# - Pinch shoulder blades, chest high.
# - Big belly breath; brace hard.
# - Squeeze the bar; “rip it in half.”
# - Eyes on one ceiling spot; throw the bar back.
#
# Camera note
# - Next time, a 45° angle from the feet side will let me assess elbow angle, bar path, and whether your hips stay down throughout the set.
#
# Training note
# - For work sets, add weight in sets of five until bar speed slows and your form starts to change, then stay at that weight for two more sets of five.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpze17tvzm
# Video name: tmpze17tvzm
# BEFORE VECTOR DB - classified_keywords: Bench Press     Feet   base    Lower back   arch    Core engagement    Shoulder position    Elbow alignment    Grip   bar positioning    Head   Neck    Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8968
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Thanks for the video—love the effort here!
#
# What I observe
# - Flat bench in a rack, no spotter. You’ve got a noticeable arch and you press to lockout each rep.
# - Heels look down, but your feet are set wide and fairly far forward; shins angle back rather than nearly vertical.
# - Elbows look a bit flared on the way down; bar touch appears high on the chest at times.
# - Head position drifts; it’s hard to tell if your eyes start directly under the bar.
# - Camera is a little high/angled, so bar path and elbow angle are tough to judge precisely.
#
# What looks good
# - Solid upper‑back arch and chest up.
# - Heels appear planted through most of the set.
#
# Main fixes
# - Foot/leg drive: Bring each foot back as far as you comfortably can while keeping the heels flat. From the front, keep your legs closer to the bench and set your feet so your shins are nearly vertical. Use the heels as the base of your drive. Keep your butt in contact with the bench the whole time.
# - Head/eye setup: Before unrack, plant your upper back and get your eyes directly under the bar. Pick a point on the ceiling and don’t let your eyes move—touch the bar to your chest and then drive it back to that fixed point every rep.
# - Upper‑back platform: Pinch your shoulder blades together and keep your head, upper back, glutes, and feet planted as your four points of contact throughout the set.
# - Arm path: During the descent, drop the elbows at roughly 45 degrees to your torso. If you’re naturally stronger with a wider grip, you can widen slightly, but keep that 45‑ish elbow angle and touch lower on the chest, not too high.
# - Unrack mechanics: Lift the bar out, not up. If unracking solo, you can keep your butt slightly elevated just for the liftoff, then drop your hips once you’ve unracked. Near maximal efforts, use a spotter for the liftoff.
# - Stability: Avoid “floppy feet.” Keep them planted and tight the whole time.
#
# Mental cues
# - Heels down, feet back, shins near vertical; knees close to the bench.
# - Pinch shoulder blades; chest high; butt stays on the pad.
# - Crush the bar and “bend it”; big breath into your gut before each rep.
# - Eyes lock on one ceiling spot; touch and press back to that spot.
#
# Programming tip
# - For the next sets of five, add a little weight until bar speed slows and form starts to change; stay there for two more sets of five for your first work set.
#
# Filming note
# - Next time, a true side view at chest height will make it easier to confirm bar path and elbow angle.
#
# Want me to mark up a photo with suggested foot/leg positions based on your bench and limb lengths?
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpz__fgob7
# Video name: tmpz__fgob7
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Glutes   legs    Core   Ribcage    Shoulder position    Grip   Wrist alignment    Bar path    Head   Neck    Elbow position    Lockout position     Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8235
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Thanks for sharing this set—love the effort and the arch you’re creating.
#
# What I observe
# - Flat barbell bench, wide grip, pronounced chest-up arch.
# - Feet are very wide and pushed forward; shins angled forward, not near vertical. Legs look loose relative to the bench.
# - Elbows appear flared and the touch point looks a bit high on the chest.
# - You’re unracking solo with a heavy load.
# - Camera angle is low/front-quarter, so bar path and elbow angle are hard to judge precisely.
#
# What looks good
# - Strong upper‑back arch and chest high, which is great for shortening the range and protecting the shoulders.
# - Wider grip can be fine if you’re stronger there.
#
# Main fixes
# - Foot position and leg drive: Set your feet farther back and closer to the bench when viewed from the front, heels flat. Aim for shins nearly vertical. Keep the four points of contact planted (head, upper back, glutes, feet) and don’t let your butt come off the bench.
# - Elbow angle and touch point: On the descent, drop your elbows to roughly 45 degrees relative to your torso and touch a consistent point on your chest, then press back in an upside‑down J.
# - Eye and bar position: Start with your eyes directly under the bar. Fix your gaze on one spot on the ceiling and drive the bar back to that spot every rep.
# - Bracing and upper back: Take a huge breath into your diaphragm, press your belly out, grip the bar as hard as you can, and “bend the bar” to keep the upper back tight.
# - Unrack: Near heavier efforts, get a spotter and lift out, not up. If you must unrack alone, briefly elevate the hips for the liftoff, then drop them to the bench before the first rep.
# - Load management: Add weight only until bar speed slows and form starts to change, then stay there for two more sets of five. If these changes feel hard to hold, lighten the load for a bit while you master them.
#
# Mental cues
# - Heels down, feet back, legs close to the bench; shins nearly vertical.
# - Chest up, shoulder blades pinched; head, back, glutes, feet planted.
# - Big belly breath and brace; crush the bar and “bend it.”
# - Elbows ~45 degrees; touch the same chest spot; throw the bar back in an upside‑down J.
# - Eyes locked on one ceiling point the whole set.
#
# One ask for the next video
# - A true side view at chest height (and a top view if possible) will let me confirm bar path and elbow angle more precisely.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpdxkjthee
# Video name: tmpdxkjthee
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet and base    Glutes and hips    Lower back and arch    Core and ribcage    Shoulder position    Elbow path    Wrist alignment    Bar path    Head and neck     Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8968
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s what I see
# - Flat bench press from a low side angle. You keep your head, torso and glutes on the bench throughout the reps. Bar speed looks controlled.
# - Your right foot is on the floor, but it looks a bit forward relative to your knee. I can’t clearly see your left foot or your grip width from this angle. Elbow angle and the exact chest touch-point are also hard to judge.
#
# What looks good
# - Four points of contact seem consistent: head/upper back/glutes on the bench and at least one foot planted.
# - Tempo looks controlled on the way down.
#
# Main fixes
# - Upper‑back setup: Before unracking, plant your upper back firmly and pinch your shoulder blades together to make a solid platform. Arch the chest up and keep it high.
# - Eye and bar position: Set up with your eyes directly under the bar. After unracking, fix your gaze on one spot on the ceiling and return the bar to that same “eye-line” each rep.
# - Foot/leg drive: Bring your feet back as far as you comfortably can while keeping the heels flat on the floor and the legs close to the bench when viewed from the front. Aim for shins nearly vertical. Use your heels as the base of your drive to reinforce your arch, but keep your butt down on the bench.
# - Descent path: Lower the bar to touch your chest (light touch, no bounce), then press back toward the ceiling spot your eyes are locked on.
# - Elbow path: During the descent, drop your elbows to roughly a 45-degree angle relative to your torso to stay tight through the shoulders.
# - Unrack mechanics: Lift the bar out, not up. If you unrack solo, you can elevate the hips for the liftoff and then set them back down once the bar is out so you keep your position.
#
# Mental cues
# - Eyes under bar, then eyes glued to one ceiling spot.
# - Pinch shoulder blades, puff chest up.
# - Heels down, shins near vertical, legs “hug” the bench; no floppy feet.
# - Squeeze the bar hard and “bend it.”
# - Touch the chest, then press back to your eye-line.
#
# Camera note
# - This low side angle makes it tough to assess grip width, elbow angle, and chest touch-point. Next time, grab a 45-degree front view and a quick clip of the unrack plus 2–3 reps.
#
# Progression tip
# - For sets of five, add a little weight until bar speed slows or your form changes; then hold that weight for two more sets of five as your first work set.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpsl7ccmy5
# Video name: tmpsl7ccmy5
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Glutes   legs    Core   Ribcage    Shoulder position    Bar path    Grip   Wrist alignment    Head   Neck    Lockout position    Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8235
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Thanks for the clips! Here’s what I’m seeing from this front-on angle of your flat barbell bench:
#
# - You’ve got an intentional arch and a high chest. Upper back looks set against the pad.
# - Bar speed looks controlled through the reps.
#
# Main fixes
# - Foot/leg drive: Your feet are way out to the sides and it looks like you’re up on your toes at times. Bring each foot back as far as you comfortably can with your legs closer to the bench when viewed from the front. Plant your heels flat and aim for nearly vertical shins. This lets you drive through your heels without your butt popping up.
# - Keep all four contact points: head, upper back, glutes, and feet should stay planted the whole set. Don’t let the butt lift.
# - Elbow path: Your elbows look quite flared. On the descent, drop them to roughly a 45-degree angle relative to your torso.
# - Bar path and gaze: Pick a single spot on the ceiling, lock your eyes there, touch the bar to your chest, then drive it back toward that spot in an upside-down J. This will keep every rep consistent.
# - Brace and grip: Before each rep, take a huge breath into your diaphragm, press your air out against your belt (if you’re wearing one), and squeeze the bar as hard as you can—think about “bending the bar” to keep your upper back tight.
# - Stability: I notice a little lower-body wobble; avoid “floppy feet.” If you feel your legs or core loosen, reset before the next rep.
# - Safety/liftoff: Near heavier efforts, use a spotter and lift the bar out (not up). If you unrack yourself, you can keep your butt slightly elevated for liftoff, then set your hips down before the first rep.
#
# Mental cues
# - Heels down, toes slightly out, feet back, shins near vertical.
# - Knees tucked in closer to the bench; butt glued to the pad.
# - Big belly breath, brace hard, squeeze the bar, “bend the bar.”
# - Elbows at ~45° on the way down; eyes locked on one ceiling point; touch-and-drive back toward that point.
#
# If you’re dialing these in, add weight in sets of five until bar speed just starts to slow and form begins to change, then stay there for two more sets of five. For the next video, a 45-degree side angle (showing bar-to-chest touch and feet) will help me check bar path and leg drive even better.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpw5lwmaow
# Video name: tmpw5lwmaow
# BEFORE VECTOR DB - classified_keywords: Bench Press      Feet   base    Glutes   legs    Lower back   arch    Core   Ribcage    Grip   Wrists    Elbow position    Bar path    Head   Neck    Lockout position     Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9204
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Thanks for the clips! Here’s what I’m seeing:
#
# - You’re on an incline bench in the Smith. Head and upper back stay on the pad through the set, and the bar is under control on the way down.
# - Feet are very wide and forward, toes turned out; shins angle forward. Grip looks on the narrow side and elbows drift out as you press. Bar touches high on the chest/neck area.
#
# What looks good
# - Heels look planted and you keep the bar moving with control.
# - Head and upper back stay in contact with the bench.
#
# Main fixes
# - Set your lower body for leg drive: bring your feet back and closer to the bench when viewed from the front so your shins are nearly vertical. Keep heels flat and hips down so your butt stays on the bench the whole set.
# - Get your eyes directly under the bar before unracking and then fix your gaze on one point on the ceiling so every rep touches the same spot.
# - Widen your grip slightly so you’re stronger and can keep your elbows about 45 degrees to your torso during the descent.
# - Pinch your shoulder blades together and use your upper back as a platform to keep your chest “high.” Maintain four points of contact: head, upper back, glutes, and feet all planted.
# - On each rep: unlock the elbows, lower to the chest with a light touch (don’t pause on the pins), then drive through your heels and “throw the bar back” toward the point you’re looking at as you press.
#
# Mental cues
# - Heels down, feet back, shins near vertical.
# - Eyes trap a spot on the ceiling; don’t move them.
# - Squeeze the bench with your shoulder blades; chest up.
# - Hands a bit wider; elbows at ~45°.
# - Touch, tighten glutes, drive the bar back.
#
# Camera tip
# - Next time, shoot a 45-degree side angle from the head end so I can see bar-to-chest touch, elbow angle, and if your hips ever lift.
#
# Programming note
# - Do a few progressive sets of five, adding a little weight until bar speed just starts to slow and form wants to change. Stay at that weight for two more sets of five to make it your first work set while you dial in these fixes.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpto1l5zq6
# Video name: tmpto1l5zq6
# BEFORE VECTOR DB - classified_keywords: I m sorry  I can t assist with identifying or evaluating individuals in photos
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: Now because there are so many errors with the squat, I may have to just do another video on just the
# CHUNK PREVIEW: Okay, so that is all that I have for the squat. Before you guys click out of the video just yet, I w
# AFTER VECTOR DB - top_k_chunks length: 6452
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Thanks for sharing this—love the effort here!
#
# What I’m seeing
# - Flat dumbbell bench press with a big arch and strong leg drive; feet tucked back close to the bench.
# - Shoulder blades look somewhat set, but your hips rise and your butt appears to lose contact with the bench on several reps.
# - Elbows flare quite a bit on the way up, and the two bells don’t travel perfectly symmetrically at the top.
# - Side angle is helpful, but it’s a little high—hard to judge elbow tuck precisely.
#
# What looks good
# - You’re creating an arch and using leg drive.
# - Tempo looks controlled, not bouncing the weights.
#
# Main fixes
# - Keep your hips down so your butt stays on the bench. Maintain the arch from your upper back, not by lifting the hips. Plant your feet solidly; if you use regulation technique, keep heels down (toes can be turned out if needed).
# - Lock in your upper back: squeeze and keep your shoulder blades retracted and depressed throughout the set.
# - Clean up elbow position. Avoid both over-tucking and flaring. Use a slight tuck on the way down; if needed, allow a touch more flare only through the sticking point. Try a few slow-eccentric, lighter sets to feel and correct your elbow path.
# - Safety/setup: double‑check matching dumbbell weights and use a spotter for hard sets.
#
# Mental cues
# - “Butt on the bench, heels planted.”
# - “Pinch shoulder blades and keep them pinched.”
# - “Slight tuck down, gentle flare through the sticking point.”
# - “Drive your back into the bench and push the floor.”
#
# If you can, next time film a little lower from the feet-end at a 30–45° angle so I can clearly see elbow tuck and hip contact.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpt_7_rjdw
# Video name: tmpt_7_rjdw
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Leg drive    Lower back and arch    Shoulder position    Grip   wrist alignment    Bar path    Elbow position    Head   Neck
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8003
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: What I see
# - Flat bench press at home with no spotter. You’ve set a noticeable arch and you’re pressing through several smooth reps.
# - Your feet look quite forward and set wide from the bench, and the bench’s foot pad is crowding your right foot. From this angle it also looks like your hips float high relative to the bench at times.
#
# What looks good
# - Solid upper‑back tightness/arch and controlled reps.
# - Hands appear set evenly on the bar and you complete each rep without wobble.
#
# Main fixes
# - Foot position/leg drive: Tuck your feet farther back and closer to the bench when viewed from the front. Aim for shins nearly vertical with heels planted flat so you can drive up the legs without your butt bridging off the pad.
# - Keep four points of contact: head, upper back, glutes, and feet all planted. Maintain the arch but make sure your butt stays touching the bench the entire set.
# - Elbow and bar path: On the descent, drop the elbows to roughly a 45-degree angle relative to your torso, “bend the bar,” touch your chest, then drive the bar back toward the spot on the ceiling your eyes are fixed on—think an upside‑down J path.
# - Setup order: Plant your back on the bench with eyes under the bar, set your feet for leg drive (heels down), then take your grip. If you’re stronger with a wider grip, widen it a bit.
# - Breathing/bracing: Big breath into your diaphragm and push your gut out to create a rigid column before every rep.
# - Camera note: This angle makes it hard to see your touch point and elbow angle. Next time, shoot a true side view at chest height plus a front view to confirm leg position.
#
# Mental cues
# - Heels down, shins vertical, feet tucked and close to the bench.
# - Pinch shoulder blades; chest high on the pad.
# - Big breath and brace the gut.
# - Bend the bar; elbows ~45°.
# - Touch, then press back to your “ceiling spot” in an upside‑down J.
# - Butt stays down; drive through the heels.
#
# If you’re working up in weight, add small increments until bar speed starts to slow and form changes, then hold that weight for two more sets of five for your first work set.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpj40xm0_w
# Video name: tmpj40xm0_w
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Glutes   legs    Core   Ribcage    Shoulder position    Grip   wrist alignment    Bar path    Head   Neck    Elbow position
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: While there are exceptions, doing squats for greater than 10 reps or so will usually cause your card
# CHUNK PREVIEW: they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum a
# AFTER VECTOR DB - top_k_chunks length: 9210
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: What I’m seeing
# - Flat bench press in a rack with high, forward J‑hooks. The bar finishes very close to the hooks.
# - Feet are up on the toes and look a bit mobile; lower body doesn’t look firmly planted.
# - Elbows appear fairly flared on the way down; bar seems to touch a bit high on the chest.
# - Upper back/shoulder blades don’t look tightly set on the bench the whole time.
# - Range looks full (bar touching chest each rep). Camera is from the head side so the bar path and forearm angle are hard to judge perfectly.
#
# What looks good
# - You’re touching your chest each rep, keeping a consistent range of motion.
# - Grip looks even and you’re keeping the bar under control.
#
# Main fixes
# - Build a solid base: Ensure four points of contact—head, upper back, glutes, and feet—are planted. Get your feet firmly set (either flat or solidly on the toes) and keep them still. Take a deep breath into your gut and brace hard; squeeze the glutes to create a stable platform.
# - Set your upper back: Pinch your shoulder blades together and use the upper back as a platform to press from.
# - Elbow path and touch point: During the descent, aim for roughly a 45-degree elbow angle relative to your torso. Touch the bar around the top‑ab to nipple line so your forearms stay close to 90 degrees to the floor at the bottom.
# - Bar path and focus: Pick a single spot on the ceiling, keep your eyes locked there, touch the chest without pausing excessively, then drive the bar back to that same spot each rep.
# - Unrack/rerack safely with these hooks: Lift the bar out (not straight up), then after the last rep lock the elbows before moving the bar back into the hooks so you don’t clip them mid‑rep.
# - Filming note: Next time, shoot from the side at mid‑chest height so we can confirm your forearm angle and exact touch point.
#
# Mental cues
# - Plant feet, squeeze glutes, big belly breath—brace.
# - Pinch the shoulder blades and stay tight.
# - Crush and “bend the bar.”
# - Elbows ~45°, touch low (top‑ab/nipple), forearms vertical.
# - Eyes fixed on one ceiling spot; press back to it.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpmk97_ys4
# Video name: tmpmk97_ys4
# BEFORE VECTOR DB - classified_keywords:   Dumbbell Bench Press       Feet   base    Lower back   arch    Core engagement    Shoulder positioning    Elbow alignment    Hand   wrist position    Dumbbell path    Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now that we've covered equipment, let's talk about what actually makes the components of a good benc
# CHUNK PREVIEW: The setup for the bench press is extremely important, and you may want to play this back a couple of
# AFTER VECTOR DB - top_k_chunks length: 7833
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s what I see
# - Flat dumbbell bench outside on a narrow bench with a towel over it. You’re pressing to full lockout each rep.
# - Feet are set wide and fairly far forward; the right heel comes up. Hips shift a bit.
# - Elbows flare out wide at the bottom, close to a “T” shape relative to your torso.
#
# What looks good
# - Solid control to the top with full elbow lockout.
# - You keep your head down and stay generally consistent rep to rep.
#
# Main fixes
# - Foot placement/leg drive: Bring your feet back as far as you comfortably can while still keeping them flat on the floor. Keep your legs closer to the bench when viewed from the front. Plant the heels and keep the hips down so your butt maintains contact with the bench—this gives you a tight base for pressing.
# - Upper‑back position: Pinch your shoulder blades together and keep your back tight and slightly arched so you’re pressing from a stable upper‑back “platform.” Don’t let your back flatten between reps.
# - Elbow path: Lower with the elbows tucked about 45 degrees (not flared straight out). This protects the shoulders and lets you engage the lats as you press.
# - Bracing and tempo: Before each rep, take a big breath and brace your abdominal wall. Lower under control, let the weights come to a complete stop at the bottom, then drive back up.
# - Small safety/camera notes: The towel can slip—bench directly on the pad for a better anchor. For a clearer form check next time, film from the foot-end or a 45° front angle so I can see elbow tuck and leg drive better.
#
# Mental cues
# - Feet back and flat; butt down.
# - Pinch shoulder blades; keep the arch.
# - Big breath and brace.
# - “Protect the armpits” (tuck to ~45°).
# - Think “bend the bar” to engage the lats as you lower, then drive straight up.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpmzdfs10n
# Video name: tmpmzdfs10n
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Glutes   legs    Lower back arch    Shoulder position    Grip and wrist alignment    Elbow position    Bar path    Head   Neck    Lockout position     Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: The next thing I want to talk about is back position. As you lie down on the bench, you want to posi
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# AFTER VECTOR DB - top_k_chunks length: 8279
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Awesome work getting these reps on video!
#
# What I observe
# - Flat bench inside a rack, side view. You touch the bar to your chest each rep and keep your butt on the pad.
# - Your touch point looks quite high on the chest and your elbows appear fairly flared. Feet are on the floor but not pulled back much, and I don’t see strong, consistent leg drive. Wrists look a bit extended behind the bar at times.
# - J-hooks look close to your press path; your eyes seem slightly behind the bar at setup.
#
# What looks good
# - Controlled touches to the chest without bouncing.
# - Head, upper back, and glutes stay on the bench throughout.
#
# Main fixes
# - Setup relative to the bar: Lie so your eyes are directly under the bar with the bar set around forehead height. This helps you unrack without drifting into the pegs and avoids hitting them when you press.
# - Upper back position: Plant your upper back hard into the bench and pinch the shoulder blades together to make a solid platform.
# - Elbow path and touch point: On the descent, drop your elbows to roughly 45 degrees from your torso. This will naturally bring the touch point a bit lower on the chest and protect the shoulders.
# - Bar path and gaze: Pick a spot on the ceiling and keep your eyes locked there. Lower, touch, then drive the bar back slightly in an upside‑down J path toward that spot.
# - Legs and feet: Set your feet as far back as is comfortable and keep them planted—no “floppy feet.” If you bench with regulation technique, keep heels down; either way, keep them glued to the floor, squeeze your glutes, and use leg drive as you press.
# - Grip and wrists: Grip the bar hard and “bend the bar.” Stack the bar over the wrist joint rather than letting it sit behind the wrist toward the fingers.
#
# Mental cues
# - Eyes under the bar; four points of contact.
# - Pinch shoulder blades; drive your back into the bench.
# - Elbows at ~45°; touch and “throw the bar back.”
# - Plant feet and squeeze glutes; push the floor.
# - Crush the bar; wrists stacked.
#
# If you can, grab one more angle from the front at about 45 degrees so I can confirm elbow angle, grip width, and foot position. Also, near heavier sets, have a spotter help with the liftoff.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpiliivon7
# Video name: tmpiliivon7
# BEFORE VECTOR DB - classified_keywords: Bench Press     Feet   base    Glutes   hips    Lower back   arch    Core   Ribcage    Grip   Wrist    Elbow position    Bar path    Head   Neck    Lockout position     Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9204
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s what I see in your bench set from the side view:
# - You’re touching the bar to your chest each rep and keeping your butt on the bench.
# - Elbows look reasonably tucked (roughly ~45°) and you’re controlling the bar down.
# - Your legs are almost straight and your feet are set far forward from the bench, so your shins angle forward instead of being near vertical. Your arch/upper‑back tightness looks minimal, and the bar seems to drift toward the uprights.
#
# What looks good
# - Butt, head, and upper back are staying on the bench throughout the rep.
# - Smooth, consistent touch to the chest with controlled tempo.
#
# Main fixes
# - Set your lower body for leg drive: bring each foot back toward the bench until your shins are nearly vertical when viewed from the side. Plant your heels flat so you can drive through them without your hips lifting. Keep your legs close to the bench when viewed from the front.
# - Build a tighter base with your upper back: pinch your shoulder blades together and use your upper back as the platform to press from. Keep the chest “high” with a reinforced arch while making sure your hips stay down on the pad.
# - Nail the setup and unrack: start with your eyes directly under the bar. Unrack by lifting out, not up, so you don’t lose your upper‑back position or bump the uprights.
# - Bar path and eye focus: fix your gaze on one spot on the ceiling. Touch the bar to your chest, then “throw it back” slightly in an upside‑down J so it finishes over the same point every rep.
# - Grip and tension: take your grip before leg/hip position changes, squeeze the bar as hard as you can, and “bend/rip the bar” to keep the upper back tight. If you find you’re stronger wider, try a slightly wider grip.
# - Keep your feet from getting “floppy”: once set, don’t let them move. Use even pressure through heel and big toe while bracing your gut with a big breath.
#
# Mental cues
# - Heels down, feet back, shins vertical.
# - Pinch shoulder blades; chest up, hips down.
# - Eyes locked on one ceiling spot; touch and drive back in an upside‑down J.
# - Squeeze the bar; “bend it” and stay tight the whole set.
# - Four points of contact: head, upper back, glutes, feet.
#
# Camera note: The side angle is helpful for bar path, but I can’t fully see heel contact. A front 45° shot next time will let me check elbow angle and foot/leg position better.
#
# Programming tip for your next session: warm up with sets of five, add a little weight until bar speed slows or form starts to change, and stay there for two more sets of five for your first work set weight.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmp_xgsk9jp
# Video name: tmp_xgsk9jp
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Lower back   arch    Glutes   legs    Core stability    Shoulder position    Elbow alignment    Wrist position    Bar path    Grip width     Head   Neck
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: While there are exceptions, doing squats for greater than 10 reps or so will usually cause your card
# CHUNK PREVIEW: they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum a
# AFTER VECTOR DB - top_k_chunks length: 9415
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s what I see
# - You’re barbell bench pressing on a flat bench with a slight arch. Plates are on the bar and collars are on—nice.
# - Your feet shift and your heels lift during the set. Your lower body looks loose.
# - Your elbows appear pretty flared and the bar path looks a bit inconsistent rep to rep.
# - You’re using a towel on the bench pad, which can make it slippery and reduce upper‑back tightness.
#
# What looks good
# - You have some arch and your glutes appear to stay on the bench.
# - The bar seems under control—no obvious bounce.
#
# Main fixes
# - Lock in the “four points of contact.” Plant head, upper back, glutes, and feet. Don’t let your feet wander—floppy feet kill tightness and pressing power. Either go toes or heels, but keep them planted and drive them into the floor.
# - Get tighter in the upper back. Pinch the shoulder blades together and use your upper back as a platform. Grip the bar hard and think about “bending the bar” to keep your back tight.
# - Tuck the elbows a bit. During the descent, keep elbows around 45 degrees relative to your torso rather than flared out; this will help you press the bar more vertically and consistently.
# - Clean up bar path and touch point. Pick a spot on the ceiling for your eyes, don’t let your gaze move, lower the bar to your chest, touch without stopping, and drive it back up toward that same ceiling point every rep.
# - Unrack smoothly. Lift the bar “out, not up,” then settle your shoulders and keep your hips and glutes planted before starting the first rep.
# - Consider removing the towel if it’s making the bench slippery so your upper back stays planted.
#
# Mental cues
# - Eyes glued to one spot on the ceiling.
# - Pinch shoulder blades; “bend the bar.”
# - Plant feet hard; knees out; squeeze glutes.
# - Elbows 45 degrees; touch chest; same touch point every rep.
#
# If you can, film a set from the feet-end at about a 45-degree angle next time so I can better check elbow angle and bar path.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpbpjc4ff0
# Video name: tmpbpjc4ff0
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   Leg position    Glute engagement    Back arch    Shoulder position    Hand placement    Bar path    Head position    Tempo and control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 9
# CHUNK PREVIEW: Now that we've covered equipment, let's talk about what actually makes the components of a good benc
# CHUNK PREVIEW: The setup for the bench press is extremely important, and you may want to play this back a couple of
# AFTER VECTOR DB - top_k_chunks length: 6987
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: What I see
# - You’re benching inside a Smith machine from a low side angle. Bar is moving straight up/down, touching around the lower chest/upper‑sternum area.
# - Head, upper back and glutes are on the bench the whole time—good control.
# - Feet are tucked back with heels off the floor most of the set, so leg drive looks limited.
# - From this angle your elbows look a bit tucked at the bottom, but it’s hard to gauge precisely because the plates block the touch point.
#
# What looks good
# - You keep your butt down and maintain control to the chest each rep—solid range.
# - Bar speed is steady and you’re not bouncing.
#
# Main fixes
# - Plant your feet flat and keep them planted. Pull them back as far as you comfortably can while still keeping them flat. This will give you a stronger base and stop “floppy feet.”
# - Lock in your upper‑back platform. Before unracking, pinch the shoulder blades together and keep them pinched so you can drive against the bench. Puff the chest up.
# - Set up so your eyes are directly under the bar and fix your gaze on one spot on the ceiling. This helps every rep touch and press from the same place.
# - Aim for about a 45-degree elbow angle to your torso on the way down. From this angle you look a bit more tucked—let the elbows open slightly so they’re neither flared nor glued to your sides.
# - On the press, tighten the glutes and drive your legs into the floor, then “throw” the bar slightly back toward the rack through lockout to trace the upside‑down J path.
# - After the last rep, finish with locked elbows before you move the bar back to rack. Near max effort, have a spotter assist with the liftoff.
#
# Mental cues
# - Feet flat, knees back; screw feet into the floor.
# - Pinch shoulder blades and puff chest.
# - Death‑grip the bar—“bend it” to stay tight.
# - Eyes on one ceiling spot; bar touches the same place every rep.
# - Squeeze glutes, drive legs, throw the bar back to lock out.
#
# Camera tip
# - This side angle hides your elbow angle and touch point. Next time, film from a front‑3/4 angle (near your feet) so I can clearly see elbow flare, bar path, and foot contact.
# Frames processed: 15, (9.033333333333333s cap)
# Saved to processed-images/tmp4b6ptxw6
# Video name: tmp4b6ptxw6
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Glutes   lower back    Core   Ribcage    Scapular position    Grip   wrist alignment    Elbow position    Bar path    Head   Neck
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: While there are exceptions, doing squats for greater than 10 reps or so will usually cause your card
# CHUNK PREVIEW: they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum a
# AFTER VECTOR DB - top_k_chunks length: 9219
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s what I see in your clips:
# - Flat barbell bench in a fixed rack, no spotter. Your grip looks a bit narrow and your wrists appear bent back at the top.
# - Feet are up on your toes and moving a little; back looks relatively flat with limited upper‑back pinch.
# - Bar touches around mid-to-upper chest and you press to a slightly different spot each rep (bar path drifts). Elbows look a bit flared at the bottom.
# - Camera angle is front‑side; helpful, but I can’t perfectly judge elbow angle or bar path from the shoulder.
#
# What looks good
# - You’re taking the bar through a full range of motion (touching the chest and locking out).
# - Tempo looks controlled overall.
#
# Main fixes
# - Set your base: Plant your four contact points—head, upper back, glutes, and feet—hard into the bench/floor. Pinch your shoulder blades together to create a solid platform to press from.
# - Feet and leg drive: Either keep feet flat or stay on your toes, but make it consistent. Push your knees out, arch a bit, take a deep breath, brace your core, and squeeze your glutes so the lower body doesn’t loosen mid‑set.
# - Elbow position and descent: On the way down, aim for roughly a 45-degree elbow angle relative to your torso. Use the “bend the bar/rip it in half” cue to naturally tuck the elbows and engage your lats.
# - Bar path and touch point: Fix your eyes on one spot on the ceiling so every rep tracks to the same place. Lower to the lower‑to‑mid chest and press back up toward that fixed ceiling spot to keep the path consistent.
# - Grip and wrist stability: Grip the bar as hard as you can and think about bending it into a U—this helps keep the wrists stacked and your upper back tight.
# - Rep quality: Touch the chest without bouncing. Keep the range of motion identical every rep to ensure you’re gaining strength from consistency, not momentum.
# - Safety: If you’re near a maximal effort, have a spotter help with the liftoff (lift out, not up).
#
# Mental cues
# - “Head, upper back, glutes, feet—locked in.”
# - “Big breath, brace, chest up.”
# - “Bend the bar and tuck to ~45°.”
# - “Touch low chest—press back to the ceiling spot.”
# - “Knees out, squeeze glutes.”
#
# If you can, next time grab one angle directly from the side (mid‑chest height) and one from the foot end to confirm elbow angle and bar path.
# Frames processed: 15, (10s cap)
# Saved to processed-images/tmpcg0rhkau
# Video name: tmpcg0rhkau
# BEFORE VECTOR DB - classified_keywords:   Bench Press       Feet   base    Glutes   lower back    Core   ribcage    Shoulder position    Elbow angle    Bar path    Head   neck    Grip width
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now because there are so many errors with the squat, I may have to just do another video on just the
# CHUNK PREVIEW: Okay, so that is all that I have for the squat. Before you guys click out of the video just yet, I w
# AFTER VECTOR DB - top_k_chunks length: 8715
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s what I see
# - You’re barbell benching in a fixed bench station with a medium‑wide grip and wrist wraps. You’ve got a solid arch and you’re tucking your feet back on your toes.
# - The bar seems to touch around mid‑chest and then drifts a bit toward your head on the way up. Your hips look close to lifting at lockout on a few reps.
#
# What looks good
# - Nice upper‑back arch and general control on the descent/touch.
# - Grip width looks reasonable for you.
#
# Main fixes
# - Keep all 4 contact points planted. Head, upper back, glutes, and feet should stay down throughout the set. If you prefer being on your toes for more arch, that’s fine—just make sure your butt still touches the bench the whole time.
# - Set your feet for stronger leg drive. Bring them back as far as comfortable and keep them tight to the bench when viewed from the front. If you use a regulation (heels‑down) style, externally rotate slightly so heels can stay planted.
# - Lock in your upper back. Squeeze shoulder blades together and keep them retracted and depressed the whole rep so you’re pressing off a stable platform rather than “reaching” at lockout.
# - Dial in elbow angle. Avoid both flared and over‑tucked elbows; aim for a slight tuck (about 45° relative to your torso) on the way down, letting them naturally flare a bit through the sticking point.
# - Standardize touch point and bar path. Keep your eyes fixed on one spot on the ceiling; lower to touch your chest (somewhere between top ab and nipple line, depending on your grip/arm length) and then drive the bar back toward that same ceiling point. Check that your forearms are vertical at the bottom—adjust grip width or touch point if they’re not.
# - Safety check when going heavy. Center the bar, confirm plates and collars are even, and use a spotter or a hand‑off so you can “lift out, not up.”
#
# Mental cues
# - Eyes glued to one ceiling spot; touch, then press back to it.
# - Pinch shoulder blades and “plant” your upper back.
# - Bend the bar and crush the grip.
# - Knees out, feet set—butt stays on the bench.
# - 45° elbows on the way down.
#
# Camera angle note: this side angle is helpful, but next time add a 45° front‑side view from the foot of the bench so I can check elbow tuck and forearm verticality more precisely.
