# %%
from langgraph.graph import StateGraph
import sys
sys.path.append('/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach')
from typing import TypedDict
import os 
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from app.chat_memory import get_chat_history
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.messages import HumanMessage
from app.video_processing import analyze_video
from vectorstore_setup import clean_classification_text
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langgraph.graph import StateGraph, START, END
from app.chat_memory import get_chat_history 
import tempfile

embeddings = OpenAIEmbeddings(model='text-embedding-3-small')
vectorstore = Chroma(persist_directory="/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/chroma_db", embedding_function=embeddings)

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGSMITH_API_KEY")


# Whisper speach to text 
from openai import OpenAI
client = OpenAI()

# %%
query_agent = ChatPromptTemplate.from_messages([
    ("system", """Your job is to classify user queries into two buckets: 
     - memory
     - memory and vectorstore
     
     *Guidelines*
     Questions regarding exercises, exercise form, or technique: vectorstore & memory
     General question or statements: memory
   
     *Respond to queries with only the correct class*
     Examples: 
     User: how should I grip the bar for bench press?
     Agent: vectorstore & memory

     User: what muscles should I feel during the Romanian dead lift?
     Agent: vectorstore & memory

     User: How's this? 
     Agent: vectorstore & memory

     User: Is this good squat technique? 
     Agent: vectorstore & memory

     User: Was my bar path better?
     Agent: vectorstore & memory

     User: thakns for your help!
     Agent: memory

"""),

     ("human", "{query}")
     
])

llm = ChatOpenAI(model='gpt-5.4-nano')

output_parser = StrOutputParser()

router_chain = (query_agent | llm | output_parser).with_config({"run_name": "router_agent"})

# %%
# Define the state

# the state is a dictionary

class GraphState(TypedDict):

    session_id: int 

    user_query: str

    user_video: str

    classification_image: str

    classified_keywords: str

    top_k_chunks: str

    encoded_images: list[str]

    response: str

# %% [markdown]
# # Router function: conditional edge

# %%
def route_query(state: GraphState):
    # first check: is there a video?
    if state["user_video"]:
        return "video_encoder"
    
    # no video — ask the router_prompt LLM which path
    route = router_chain.invoke({"query": state["user_query"]})
    route = route.lower().strip()
    
    if "vectorstore" in route:
        return "vector_db"
    else:
        return "chat_memory"

# %% [markdown]
# # Video Encoder Node

# %%
def video_encoder_node(state: GraphState):
    user_video = state["user_video"]
    user_video_encoded = analyze_video(filepath_in=user_video, frame_count=15, max_seconds=10) # encodes video
    encoded_images = [] # creates a list of encoded images for LLM
    for images in user_video_encoded:
        encoded_images.append({"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{images}"}})
        classification_image = user_video_encoded[0] 
    
    return {"classification_image": classification_image, "encoded_images": encoded_images}

# %% [markdown]
# # Video Classification Node

# %%
# video classification router NODE

def video_classification_node(state: GraphState):
    classification_image = state["classification_image"]

    router_llm = ChatOpenAI(model='gpt-5.4-nano', temperature=0.0)

    response = router_llm.invoke([

    {"role": "user", "content": 

    [{"type": "text", "text":  """Your job is to analyze images of users working out for proper form, and list the key checkpoints of their to body evaluate. 
    Give me ONLY the bodypart checkpoints. Do NOT include evaluation suggestions. Do NOT include an intro sentence. 
    Output format should be exactly the example below.
    **Example**
    Overhead press

    1. Feet & base
    2. Glutes & legs
    3. Core & Ribcage
    4. Shoulder position
    5. Bar path
    6. Head & Neck
    7. Lockout position
    8. Tempo and control
    """},


        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{classification_image}"}}
        ]}


    ])

    classified_keywords = clean_classification_text(response)

    return {"classified_keywords": classified_keywords}

# %% [markdown]
# # VectorDB Node

# %%
def vector_db_node(state: GraphState):
    user_query = state["user_query"]
    classified_keywords = state.get("classified_keywords", "")
    retrieval_query = classified_keywords

    if classified_keywords:
        results_user = vectorstore.similarity_search(user_query, k=5)
        results_video = vectorstore.similarity_search(retrieval_query, k=5)
        results = results_user + results_video

    if not classified_keywords: 
        results_user = vectorstore.similarity_search(user_query, k=5)
        results = results_user

    unique_results = []
    seen = set()

    for r in results:
        content = r.page_content
        if content not in seen:
            seen.add(content)
            unique_results.append(r)


    top_k_chunks = "\n".join([r.page_content for r in unique_results])

    print(f"RESULTS COUNT: {len(results)}")
    print(f"UNIQUE RESULTS COUNT: {len(unique_results)}")
    for r in unique_results[:2]:
        print(f"CHUNK PREVIEW: {r.page_content[:100]}")

    return {"top_k_chunks": top_k_chunks}

# %% [markdown]
# # Response Generator Node

# %%
def response_generator(state: GraphState):
    top_k_chunks = state['top_k_chunks']
    encoded_images = state.get("encoded_images", [])
    session_id = state["session_id"]
    user_query = state["user_query"]
    classified_keywords = state.get("classified_keywords", "")

    response_generator_prompt = ChatPromptTemplate.from_messages([
            ("system", """You are a world-class fitness coach. You have extensive experience in helping weight lifters achieve perfect form and maximum hypertrophy. 
    Your job is to analyze images of users lifting weights, offer them advice from your context, and to answer any questions they might have. 
    Look for issues related to form, safety, and unhelpful camera angles.
    Be specific about what you observe and include that in your feedback.
    Do not make any mention to "frames". To the user, you are watching a video.
             
             
    # HOW TO RESPOND

    Decide which mode you're in based on the user's message:

    **Mode A — Initial video analysis**:

    Analyze the lift in this fixed order. For each section, either identify a specific issue or state the section looks correct:

    1. Setup and starting position
    2. Lifting phase (concentric) — the effort portion
    3. Lowering phase (eccentric) — the controlled return
    4. Range of motion and completion — did the rep finish at full range, top and bottom?

    After the structured analysis, end with ONE offer for a next step (e.g., "If you want, I can also...").

    If the frames don't clearly show a phase, say so rather than guessing.

    **Mode B — Follow-up question** (user asks a specific question, e.g. "why does X matter?", "how do I fix Y?", "what about Z?"):
    - Answer the question directly using the context below
    - Do NOT re-describe the video or repeat your earlier analysis
    - Do NOT restart with "What I'm seeing in your bench" or similar
    - Reference the user's specific lift only if it's directly relevant to the answer
    - Keep it focused and conversational
    - Maximum 150 words

    # TONE
    Eager and excited to help.
             
    # CONTEXT
    Use ONLY the following context for coaching advice:
    {top_k_chunks}
    
    If the query or image isn't in context, reply, 'I don't have expert coaching advice for this exercise yet. 
    Currently I can analyze: bench press, overhead press, incline bench press...'"
        
    ---  


    """),
        MessagesPlaceholder(variable_name="history"),
        MessagesPlaceholder(variable_name="input"),
    ])

    user_msg = HumanMessage(content=[
        {"type": "text", "text": user_query},
        *encoded_images,   # <- your list of {"type":"image_url",...}
    ])

    response_generator_llm = ChatOpenAI(model='gpt-5.4',
                    temperature=0.5)

    response_generator_output_parser = StrOutputParser()

    response_generator_chain = response_generator_prompt | response_generator_llm | response_generator_output_parser


    message_history = get_chat_history(session_id)

    fitness_analysis = response_generator_chain.invoke(
        {   "input": [user_msg], 
            'history': message_history.messages, 
            "top_k_chunks": top_k_chunks, 
            "classified_keywords": classified_keywords}
            )


    memory_summary_prompt = ChatPromptTemplate.from_messages([
        ("system", """
    Summarize this fitness analysis for future follow-up questions.
    Keep only facts needed for chat continuity.

    Return:
    - exercise
    - main issues
    - priority fixes
    - important uncertainties
    - concise coaching summary

    Maximum 150 words.
    """),
        ("human", "{fitness_analysis}")
    ])

    memory_summary_llm = ChatOpenAI(model='gpt-5.4-nano')
    memory_summary_output_parser = StrOutputParser()
    memory_summary_chain = memory_summary_prompt | memory_summary_llm | memory_summary_output_parser

    summarized_response = memory_summary_chain.invoke({"fitness_analysis": fitness_analysis})
    message_history.add_user_message(user_query) # save user query to memory
    message_history.add_ai_message(summarized_response) # save summarized response to memory


    return {"response": fitness_analysis} # return full analysis to user

# %% [markdown]
# # Chat Memory node

# %%
# module level - built once when file loads 
chat_memory_prompt = ChatPromptTemplate.from_messages([
            ("system", """You are a world-class fitness coach. 
             You have extensive experience in helping weight lifters achieve perfect form and maximum hypertrophy. 
    Your job is to analyze images of users lifting weights, offer them advice from your context, and to answer any questions they might have. 


    """),
        MessagesPlaceholder(variable_name="history"),
        MessagesPlaceholder(variable_name="input"),
    ])

   
chat_memory_llm = ChatOpenAI(model='gpt-5.4-nano', temperature=0.5)
chat_memory_output_parser = StrOutputParser()

chat_memory_chain = chat_memory_prompt | chat_memory_llm | chat_memory_output_parser

chat_memory_with_history = RunnableWithMessageHistory(
    chat_memory_chain,
    get_session_history=get_chat_history,
    input_messages_key="input",
    history_messages_key="history"

)

# Function: calls only what changes
def chat_memory(state: GraphState):
    user_query = state["user_query"]
    session_id = state["session_id"]

    user_msg = HumanMessage(content=[
        {"type": "text", "text": user_query}
    ])

    response = chat_memory_with_history.invoke(
    {"input": [user_msg]},
    config={"configurable": {"session_id": session_id}}
)
    return {"response": response}

# %% [markdown]
# # Audio transcription function

# %%
# def transcribe_audio(audio_path):
#     audio_file = open(audio_path, "rb") # rb = read binary. audio files are binary data (raw bytes). this tells python gto open as binary instaed of text
#     transcription = client.audio.transcriptions.create(
#         model="whisper-1",
#         file=audio_file
#     )
# def transcribe_audio(audio_path):
#     audio_file = open(audio_path, "rb") # rb = read binary. audio files are binary data (raw bytes). this tells python gto open as binary instaed of text
#     transcription = client.audio.transcriptions.create(
#         model="whisper-1",
#         file=audio_file
#     )

#     return transcription.text
    

# user_query = transcribe_audio("/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/raw_voice_notes/use_your_lats.m4a")
# print(user_query)

# %%
# rebuild graph fresh each time this cell runs
workflow = StateGraph(GraphState)

# conditional edge
workflow.add_conditional_edges(START, route_query)

# add nodes
workflow.add_node("video_encoder", video_encoder_node)
workflow.add_node("video_classification_router", video_classification_node)
workflow.add_node("vector_db", vector_db_node)
workflow.add_node("response_generator", response_generator)
workflow.add_node("chat_memory", chat_memory)



# connect them
workflow.add_edge("chat_memory", END)
workflow.add_edge("video_encoder", "video_classification_router")
workflow.add_edge("video_classification_router", "vector_db")
workflow.add_edge("vector_db", "response_generator")
workflow.add_edge("response_generator", END)

app = workflow.compile()

# %%
result = app.invoke({
    "session_id": 116,
    "user_query": "how is my form here?",
    "user_video": "/Users/chandlershortlidge/Desktop/Ironhack/fitness-form-coach/data/raw_workout_videos/bench_press/bench_14.mp4"
})

print(result["response"])
# Out:
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpyduwfkou/bench_14
# Video name: bench_14
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: an erect upright posture during the positive, I'm not a big fan of the chest up cue myself since it
# Nice work — this is a solid bench overall. Here’s the breakdown:
#
# 1. **Setup and starting position**
# Your setup looks mostly correct. You’ve got an arch, your upper body stays planted on the bench, and your feet are set wide and stable. One thing to improve: your feet look a bit too far out and not ideal for strong leg drive. I’d bring them slightly farther back so you can push more effectively into the floor while keeping your glutes down on the bench.
#
# 2. **Lifting phase (concentric)**
# The press looks controlled and steady. You’re driving the bar up without any major wobble. Elbow position also looks fairly good — not excessively flared. I do notice the bar path looks a little inconsistent, with the bar drifting slightly during the press instead of following the same groove each rep.
#
# 3. **Lowering phase (eccentric)**
# This part looks pretty good. You lower the bar under control and bring it down to a consistent touch point on the chest. Your elbows appear reasonably tucked, which is a good sign for shoulder safety.
#
# 4. **Range of motion and completion**
# You are getting full reps. The bar reaches the chest and you press back to lockout. That part looks correct.
#
# Biggest fix: **improve foot position for stronger leg drive and a more repeatable bar path**. If you want, I can also give you 3 specific cues to make your bench feel stronger right away.

# %%
# result = app.invoke({
#     "session_id": 114,
#     "user_query": user_query,
#     "user_video": ""
# })

# print(result["response"])

# %%
# result = app.invoke({
#     "session_id": 115,
#     "user_query": "what did you say about foot pressure?",
#     "user_video": ""
# })

# print(result["response"])

# %%
# result = app.invoke({
#     "session_id": 115,
#     "user_query": "thanks!",
#     "user_video": ""
# })

# print(result["response"])

# %%
def correctness_evaluator(run, example):
    generated = run.outputs["answer"]
    reference = example.outputs["answer"]
    question = example.inputs["user_query"]

    prompt = f"""You are evaluating a fitness coaching AI assistant.
Your job is to assess the quality of its response against a reference answer. 
The reference answer contains the minimum key observations. The generated answer may expand on these with additional coaching advice and this should not be penalized.

Question: {question}
Reference answer: {reference}
Generated answer: {generated}

Scoring criteria:

Score 0 — The generated answer contains incorrect or potentially harmful advice that contradicts the reference answer. This is the worst outcome.
Score 1 — The generated answer is incomplete or omits important details from the reference, but contains nothing incorrect or harmful.
Score 2 — The generated answer is correct and captures the key facts from the reference answer.

Important: Penalize incorrect advice more harshly than omission. A response that says nothing is better than one that says something wrong.

Reply with only the number: 0, 1, or 2."""

    from openai import OpenAI
    openai_client = OpenAI()
    result = openai_client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt}]
    )
    try: 
        score_raw = result.choices[0].message.content.strip()
        score = int(''.join(filter(str.isdigit, score_raw))[0])
    except Exception as e:
        print(f"Error parsing score: {e}, raw output: {score_raw}")
        score = -1
    return {"key": "correctness", "score": score / 2} # normalize the score for LangSmith configurations

# %%
def hallucination_evaluator(run, example):
    generated = run.outputs["answer"]
    context = run.outputs["context"]
    
    prompt = f"""YYou are evaluating a fitness coaching AI assistant for hallucinations.

This AI analyzes workout VIDEOS and uses retrieved coaching context to provide form advice. 
The AI has two information sources:
1. Retrieved text context (coaching knowledge)
2. Video frames of the user's actual lift (visual observations)

<Instructions>
  - Claims about coaching best practices (e.g. "elbows should be 45-60 degrees") should be verified against the retrieved context
  - Claims about what the user is DOING in their video (e.g. "your elbows are flaring wide") are visual observations and should NOT be penalized for not appearing in the retrieved context
  - Only flag a claim as hallucinated if it contradicts the retrieved context or makes up coaching advice not supported by the context
  - Observations about the user's form that are plausible given a workout video should be treated as valid even if not in the context
</Instructions>

Retrieved context:
{context}

Generated answer:
{generated}

Scoring criteria:

Score 0 — The answer contains coaching advice that directly contradicts the retrieved context, or invents training recommendations with no basis in the context. This is the worst outcome.
Score 1 — The coaching advice is mostly supported by the context but includes minor unsupported recommendations.
Score 2 — All coaching advice and recommendations are directly supported by the retrieved context. Visual observations about the user's form do not count against this score.

Reply with only the number: 0, 1, or 2."""

    from openai import OpenAI
    openai_client = OpenAI()
    result = openai_client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt}]
    )
    try:
        score_raw = result.choices[0].message.content.strip()
        score = int(''.join(filter(str.isdigit, score_raw))[0])
    except:
        score = None
    return {"key": "hallucination", "score": score / 2} # normalize the score

# %%
from uuid import uuid4

def run_rag_pipeline(inputs: dict, attachments: dict) -> dict:
    # grab video from attachments in LangSmith
    video_name = list(attachments.keys())[0] 
    # read the video as raw bytes
    video_bytes = attachments[video_name]["reader"].read()
    
    # save to temp file because analyze_video expects a filepath
    with tempfile.NamedTemporaryFile(suffix=".mp4", delete=False) as tmp:
        # . delete=False means "don't delete this file when we're done writing" because we still need it for the pipeline.
        tmp.write(video_bytes)
        tmp_path = tmp.name
    
    state = {
        "user_query": inputs["user_query"],
        "session_id": f"eval-{uuid4()}",
        "classified_keywords": "",
        "encoded_images": [],
        "user_video": tmp_path
    }
    
    state = {**state, **video_encoder_node(state)}
    state = {**state, **video_classification_node(state)}
    print(f"BEFORE VECTOR DB - classified_keywords: {state.get('classified_keywords', 'MISSING')}")
    state = {**state, **vector_db_node(state)}
    print(f"AFTER VECTOR DB - top_k_chunks length: {len(state.get('top_k_chunks', ''))}")
    state = {**state, **response_generator(state)}

    print("STATE KEYS:", state.keys())
    print("RESPONSE:", state.get("response", "NOT FOUND"))
    
    return {"answer": state["response"],
            "context": state["top_k_chunks"]}

# %%
from langsmith import Client
from langsmith.evaluation import evaluate

langsmith_client = Client()

os.environ["LANGCHAIN_TRACING_V2"] = "false" 
# stops LangSmith from trying to log all the big intermediate data
# evaluate() function will still capture your inputs, outputs, and evaluator scores
# it just won't try to upload the full trace with all those heavy frames.
# 
results = evaluate(
    run_rag_pipeline,
    data="Image assessment accuracy v1 — variance subset (5)",
    evaluators=[correctness_evaluator, hallucination_evaluator],
    experiment_prefix="test02-system-prompt-scaffold-update",
    num_repetitions=10,
)
# Out:
# View the evaluation results for experiment: 'test02-system-prompt-scaffold-update-7f3f5559' at:
# https://smith.langchain.com/o/5dffb1fc-82e5-4000-a9a5-d9c923e0f73c/datasets/d8117071-d366-420a-ae45-b8b56c0be8fb/compare?selectedSessions=2ce1d951-dd09-4250-8b5c-462aa10073a8
# 0it [00:00, ?it/s]
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpksdmet19/tmp78n5jup9
# Video name: tmp78n5jup9
# BEFORE VECTOR DB - classified_keywords: Bench press     Setup   grip width    Wrist position   forearm angle    Shoulder position  scapula set     Elbow tracking    Bar height over chest    Chest   upper torso alignment    Core bracing   ribcage position    Lower body contact  feet planted stance     Back arch   glute engagement     Bar path  bottom position to press
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8884
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: You’re doing a lot right here. This looks like a solid beginner-to-intermediate bench pattern, and the reps appear controlled.
#
# **1. Setup and starting position**
# Mostly correct. Your **head, upper back, glutes, and feet** all appear to stay in contact with the bench/floor, which is great. Your **butt stays down**, which is a big safety and technique win.
# Main issue: your **feet look a bit far forward**, which limits leg drive. I’d like to see your feet pulled **farther back underneath you** if comfortable, with the feet staying firmly planted. That usually helps keep the chest higher and the whole body tighter.
#
# **2. Lifting phase (concentric) — the effort portion**
# Looks correct overall. You press the bar back up under control without obvious wobbling. Your elbows also seem reasonably tucked rather than flaring excessively, which is good.
# One thing to clean up: keep thinking about **staying tight through the upper back and squeezing the bar hard** so every rep looks identical.
#
# **3. Lowering phase (eccentric) — the controlled return**
# Looks controlled. You’re not crashing the bar down, which is good. The bar path appears steady from this angle.
# What’s hard to confirm from this side view is your exact **elbow angle relative to your torso**. Ideally, keep the elbows around **45 degrees**, and think about “**bending the bar into a U**” on the way down to help keep them tucked.
#
# **4. Range of motion and completion — did the rep finish at full range, top and bottom?**
# This looks good. You appear to **touch the chest** and return to a strong top position with the elbows extended. I don’t see obvious short reps.
#
# One camera note: this side angle is decent for bar path, but a **front-diagonal angle** would make it easier to judge grip width, elbow tuck, and whether your feet are giving you strong leg drive.
#
# If you want, I can also give you **3 specific cues to improve your bench on your very next set**.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpnf3k3_4n/tmp0yshn0ix
# Video name: tmp0yshn0ix
# BEFORE VECTOR DB - classified_keywords: Bench press  barbell      Foot placement   leg drive    Glutes   hip position    Lower back   ribcage position    Shoulder blades  scapular set     Upper back Thoracic extension    Elbow position   forearm angle    Bar path  bar position relative to chest     Wrist alignment    Grip width   hand spacing     Head   neck position     Rep control at bottom position     Lockout position  arms shoulders
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: The next thing I want to talk about is back position. As you lie down on the bench, you want to posi
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# AFTER VECTOR DB - top_k_chunks length: 8159
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: 1. **Setup and starting position**
# Overall, this looks pretty solid. Your eyes appear close to directly under the bar, and your head, upper back, glutes, and feet all seem in contact with the bench/floor consistently, which is a good base. Your foot position looks stable, but your feet are set fairly far forward, so you may be leaving some leg drive on the table. If comfortable, try bringing your feet a bit farther back while keeping your glutes down on the bench. Your grip width looks reasonable. One thing I’d clean up is wrist stacking: the bar appears to sit a little high toward the hands/fingers rather than clearly over the heel of the palm, so try to keep the bar directly stacked over the wrist joint.
#
# 2. **Lifting phase (concentric) — the effort portion**
# The press looks smooth and controlled, and the bar comes up evenly without a big tilt side to side. Nice job there. Your elbows also look fairly well positioned rather than excessively flared. The main thing to improve is keeping the upper back tight as you press—think about driving your upper back into the bench and gripping the bar hard. That will usually make the bar path cleaner and the press stronger off the chest.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# This phase looks controlled, which is great. You’re not just dropping the bar. The elbows appear to come down in a pretty good path, roughly in the safer tucked range rather than straight out to the sides. I do notice the bar travels a touch high on your torso near the upper chest area. That can be fine if it’s consistent, but make sure you’re lowering with the forearms staying stacked and the elbows around that 45-degree angle.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# You’re getting full reps. The bar reaches the chest at the bottom and you return to a solid lockout at the top. That part looks correct. I don’t see obvious short reps here.
#
# Big picture: good control, good consistency, and a solid base. Your biggest opportunities are **better wrist stacking** and **a stronger lower-body setup for more leg drive**. If you want, I can also give you 3 simple cues to make your bench feel stronger immediately.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpvh1dhjd2/tmpeh1wa747
# Video name: tmpeh1wa747
# BEFORE VECTOR DB - classified_keywords: Bench press  barbell      Feet   base    Glutes   hip position    Lower back   ribcage position    Shoulder blade position    Shoulder joint alignment    Elbow position    Forearm   wrist alignment    Bar path  relative to chest shoulders     Head   neck position     Bar to chest contact point     Lockout position  upper body alignment
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: While there are exceptions, doing squats for greater than 10 reps or so will usually cause your card
# CHUNK PREVIEW: they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum a
# AFTER VECTOR DB - top_k_chunks length: 9450
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Yes — overall this looks pretty solid, but I do see a few things to clean up on your bench press.
#
# 1. Setup and starting position
# Your grip width looks reasonable, and your feet are on the floor, which is good. Your upper body position looks a bit loose though — I’d like to see more upper-back tightness and shoulder blades pulled together harder to create a more stable base on the bench. Your feet also look a little casual rather than firmly planted for full-body stability.
#
# 2. Lifting phase (concentric) — the effort portion
# The press goes up successfully, but the bar path looks slightly inconsistent and a little wobbly from rep to rep. That usually means you could benefit from gripping the bar harder and keeping your upper back tighter throughout the press.
#
# 3. Lowering phase (eccentric) — the controlled return
# The lowering phase looks controlled overall. One thing I do notice is that you seem to be doing touch-and-go reps, bouncing fairly quickly off the chest rather than showing a clearly controlled touch. That can make reps less consistent and reduce your ability to build strength from the bottom.
#
# 4. Range of motion and completion — did the rep finish at full range, top and bottom?
# This looks good. You appear to be touching the chest and pressing back to near full lockout, so your range of motion is solid.
#
# Biggest fixes:
# - Retract your shoulder blades harder and keep them pinned
# - Plant your feet more aggressively
# - Slow the touch on the chest slightly so it’s controlled, not bouncy
# - Squeeze the bar hard to improve bar path consistency
#
# If you want, I can also give you 3 simple cues to improve your next set immediately.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmp0215k1nu/tmpsmz_jxu8
# Video name: tmpsmz_jxu8
# BEFORE VECTOR DB - classified_keywords: Bench press  barbell      Feet   base of support      Glutes   hip position      Low back   ribcage position      Scapula position  retraction depression       Shoulder position  rotation and elevation       Elbow position  angle and tracking       Forearms   wrist alignment      Grip width   hand placement      Bar path alignment toward chest       Head   neck position
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9038
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: You’re doing a lot right here, and this is a solid bench base. Here’s the breakdown:
#
# **1. Setup and starting position**
# Mostly correct. Your upper back looks planted on the bench, you’ve got a visible arch, and your glutes appear to stay in contact with the bench, which is good. Biggest setup issue: your feet look a bit too far forward for strong leg drive, and your heels don’t look firmly planted. I’d bring your feet farther back so your shins are closer to vertical and make sure the heels stay down. That should help you create more whole-body tightness and a stronger press.
#
# **2. Lifting phase (concentric) — the effort portion**
# Looks pretty good overall. The bar comes up smoothly without a major stall, and you’re not doing anything obviously unsafe. One thing to clean up: your body looks a little loose through the legs, so you may be missing leg drive that would reinforce your arch and keep the chest high as you press.
#
# **3. Lowering phase (eccentric) — the controlled return**
# This looks controlled. You’re bringing the bar down under control rather than dropping it, which is exactly what you want. Your elbows also appear reasonably tucked instead of flaring hard, which is a good sign.
#
# **4. Range of motion and completion — did the rep finish at full range, top and bottom?**
# Looks correct. You’re touching the bar to the chest and pressing back to lockout. Range of motion appears complete at both ends.
#
# One camera note: this angle is decent for lower-body setup and bar path, but a side view at bar height would make it much easier to judge whether your forearms stay vertical and whether your touch point is ideal. If you want, I can also give you 3 specific cues to improve your bench on your very next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpmrgu76q6/tmp3ux97kms
# Video name: tmp3ux97kms
# BEFORE VECTOR DB - classified_keywords: Barbell bench press     Feet   base    Legs   knee alignment    Glutes   lower back contact    Shoulder blades  scapula set     Upper back ribcage position    Bar path  vertical over torso     Elbow position   forearm angle    Wrist position   bar grip    Head   neck position     Range of motion  bar to chest pressing depth      Lockout position  top alignment
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9231
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: 1. **Setup and starting position**
# Your upper back looks planted on the bench, and you’ve got a visible arch, which is good. The biggest setup issue is your lower body: your feet are very wide and don’t look firmly planted for efficient leg drive. I’d bring your feet farther back and a bit closer to the bench, with heels flat if you can manage it comfortably. Your glutes should stay in contact with the bench the whole time. Also, the camera angle is workable, but a side angle would make bar path and elbow position easier to judge.
#
# 2. **Lifting phase (concentric) — the effort portion**
# You are getting the bar up, but the press looks uneven side to side. One arm appears to lock out slightly ahead of the other, which can mean you’re losing tightness or force transfer through the upper back. I’d focus on gripping the bar hard, keeping the shoulder blades pinned, and driving your legs into the floor as the bar leaves the chest.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# The descent looks generally controlled. Your elbows appear somewhat flared rather than staying around a 45-degree angle to your torso. Tucking slightly more would likely give you a stronger, safer bottom position and better pressing mechanics.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# You appear to reach the chest at the bottom and press back to lockout at the top, so the range of motion looks complete. The one thing to watch is consistency of the touch point and lockout timing between arms.
#
# If you want, I can also give you 3 specific cues to clean this up on your very next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpwxx_h3m4/tmpu1imgzf1
# Video name: tmpu1imgzf1
# BEFORE VECTOR DB - classified_keywords: Bench press  barbell      Feet   base    Glutes contact with bench    Back position  upper mid lower     Scapula position  retraction depression     Shoulder position  humerus alignment     Elbow position  angle   tracking     Wrist   bar position    Head   neck position    Arch height  ribcage control      Bar path  from setup to press
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8972
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: 1. **Setup and starting position**
# Mostly solid. Your head, upper back, and glutes look planted on the bench, and your feet stay in contact with the floor, which is good. One thing I’d clean up: your feet look a bit far forward, which can limit leg drive. Try bringing them back as far as you comfortably can while keeping your heels down and your glutes on the bench. Your upper back also looks a little relaxed rather than tightly set, so think about pinching the shoulder blades together and keeping your chest high before you start.
#
# 2. **Lifting phase (concentric) — the effort portion**
# This looks controlled and fairly consistent. The bar comes up smoothly without obvious wobbling. One issue: the press looks a little too straight up from the chest instead of slightly back toward over-the-shoulder position. Think about “throwing the bar back” as you press so the lockout finishes in a stronger position.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# The lowering looks controlled, which is good. Your elbows appear reasonably tucked rather than flared hard out, and that’s a positive for shoulder safety. From this angle I can’t clearly judge whether both shoulders are staying equally tight throughout, so I wouldn’t guess beyond that.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# You appear to reach the chest at the bottom and return to full lockout at the top, so the reps look complete. Range of motion looks good overall.
#
# Big picture: good base, especially control and consistency. The main upgrades would be **tighter upper-back setup, feet a bit farther back, and more leg drive to help send the bar slightly back on the press**. If you want, I can also give you 3 simple cues to focus on for your next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpojym1slr/tmpuo4yaqr2
# Video name: tmpuo4yaqr2
# BEFORE VECTOR DB - classified_keywords: Bench press     Grip width   hand position      Wrist alignment      Elbow position      Shoulder position  scapula set       Upper back   lats engagement      Chest position      Trunk position  ribcage   torso arch       Glute contact   leg drive      Hip position       Knee   foot placement       Neck   head position       Bar path over shoulders       Lockout finish position  arm extension
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: The next thing I want to talk about is back position. As you lie down on the bench, you want to posi
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# AFTER VECTOR DB - top_k_chunks length: 8055
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: You’re looking solid overall — this is a pretty controlled bench press. Here’s the breakdown:
#
# **1. Setup and starting position**
# Mostly correct. Your eyes appear close to under the bar, and your head, upper back, glutes, and feet look planted. Good stability on the bench. One thing I’d clean up: your feet look set a bit casually rather than tucked back for stronger leg drive. If you can, bring them back as far as is comfortable while keeping your glutes on the bench.
#
# **2. Lifting phase (concentric) — the effort portion**
# This looks good overall. You press the bar up under control without a big loss of position. I’d like to see a little more “throw the bar back” toward the rack as you approach lockout, since the press looks slightly straight up from the chest rather than following a stronger back-and-up path.
#
# **3. Lowering phase (eccentric) — the controlled return**
# Also looks good. You bring the bar down with control and touch the lower chest/upper chest area consistently. Your elbows look reasonably tucked instead of flaring excessively, which is a strong sign.
#
# **4. Range of motion and completion — did the rep finish at full range, top and bottom?**
# Looks correct. You’re touching the chest and returning to a solid top position. Lockout appears complete on the reps shown.
#
# Big picture: good control, good consistency, and no obvious dangerous issue. The main improvement would be tighter lower-body setup for better leg drive and a slightly better back-toward-lockout bar path.
#
# If you want, I can also give you 3 specific cues to make your next set stronger immediately.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmphzyq4et9/tmp_lnof1jl
# Video name: tmp_lnof1jl
# BEFORE VECTOR DB - classified_keywords: Bench dip   plate raise  front rack to overhead extension      Feet   base of support      Lower body  hips  glutes  hamstrings       Core   ribcage position      Upper back  scapula set       Shoulder position  glenohumeral joint       Elbow alignment      Wrist hand grip position      Bar plate path  relative to body       Head   neck position
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: While there are exceptions, doing squats for greater than 10 reps or so will usually cause your card
# CHUNK PREVIEW: they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum a
# AFTER VECTOR DB - top_k_chunks length: 9284
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Yes — overall this looks like a solid start, but I do see a few things to clean up on your bench press.
#
# **1. Setup and starting position**
# Mostly correct. Your feet stay planted and your body position looks fairly stable on the bench. One issue is that your upper-back tightness and chest position could be stronger. I’d like to see your shoulder blades pulled together harder and your chest kept more “proud” so you have a firmer base to press from. The camera angle is also a bit limited by the rack upright, so your full bar position relative to your shoulders is partially blocked.
#
# **2. Lifting phase (concentric) — the effort portion**
# The press looks controlled, but the bar path appears slightly uneven from side to side, with one arm looking like it rises a touch differently than the other. That can mean you’re not keeping equal tension through both hands/shoulders. Focus on gripping the bar harder and pressing evenly.
#
# **3. Lowering phase (eccentric) — the controlled return**
# This phase looks decent overall. You are bringing the bar down under control. I’d still like to see consistent elbow positioning at about a 45-degree angle from your torso rather than letting them drift.
#
# **4. Range of motion and completion — did the rep finish at full range, top and bottom?**
# The bottom looks good: you are touching the chest. At the top, you appear close to lockout, but a couple reps look just short of a fully consistent finish. Make every rep reach the same top position so you’re progressing with true full range of motion.
#
# If you want, I can also give you 3 simple cues to fix these issues on your very next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmp7orf0yas/tmprfspuf0t
# Video name: tmprfspuf0t
# BEFORE VECTOR DB - classified_keywords: Bench press     Feet   base of support      Legs   glutes      Pelvis   lower back position      Core   ribcage expansion      Shoulder blades  scapular set       Upper back   thoracic spine alignment      Elbow position   forearm angle      Wrist alignment      Bar handle position relative to chest       Head   neck position       Grip width   hand placement       Range of motion to bottom position       Lockout posture  shoulder elbow extension
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9280
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Nice work — this looks like a bench press, and there are a few things you’re doing well already.
#
# 1. **Setup and starting position**
# Your upper back looks planted on the bench, and you’ve created a solid arch. Your glutes appear to stay in contact with the bench, which is good. One issue: your feet look a bit too far forward for stronger leg drive. I’d like to see them set farther back, with heels firmly planted if you can manage it comfortably. That usually helps reinforce the arch and keep the chest high. The camera angle is decent for lower-body setup, but it makes it hard to judge whether your eyes are directly under the bar and whether your shoulder blades are fully pinned back.
#
# 2. **Lifting phase (concentric) — the effort portion**
# The bar comes up smoothly and you’re controlling it well. Your body position stays fairly still, which is a good sign. I do notice a slight unevenness in the press at times, with one side appearing to rise a little faster than the other. Focus on gripping the bar hard and pressing evenly through both arms while keeping your upper back tight.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# This part looks controlled overall. You’re not just dropping the bar. Your elbows appear reasonably tucked rather than flared excessively, which is a positive. From this angle, I can’t clearly confirm whether your forearms stay stacked directly under the bar the whole way down.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# You are touching the bar to the chest and returning to a strong top position. Lockout looks complete on the reps shown. Range of motion looks good.
#
# If you want, I can also give you 3 specific cues to clean up your leg drive and make the bar path more stable.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpoz8xf59_/tmppa_i9x72
# Video name: tmppa_i9x72
# BEFORE VECTOR DB - classified_keywords: Barbell bench press     Feet   base  stance width  foot pressure     Glutes   lower body  glute contact  leg tension     Lower back   pelvis  arch tuck position     Shoulder blades  retraction depression  contact     Upper back  thoracic extension     Elbow position  angle at start mid     Hands   grip  wrist alignment  grip width     Bar path relative to chest  line from setup to press     Shoulder joint position  rotation impingement position      Head   neck  neutral alignment  head position      Lockout position  elbow extension  shoulder control      Tempo and control  bottom position position  drive phase
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9202
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s a bench press breakdown based on what I can see in the video:
#
# 1. **Setup and starting position**
# Your upper back looks planted and you’ve got a noticeable arch, which is good. Your glutes appear to stay on the bench, also good. The main issue is your lower body setup: your feet are set very wide and turned out, and your heels don’t look firmly planted in a strong leg-drive position. I’d bring your feet a bit farther back and closer to the bench, with heels flat if your mobility allows. Also, this angle makes it a little hard to judge whether your eyes started directly under the bar.
#
# 2. **Lifting phase (concentric) — the effort portion**
# You press the bar up successfully and the bar stays fairly controlled. One thing I notice is some unevenness side-to-side, especially as the weight gets harder. Try to drive both hands into the bar evenly and keep your whole body tight through the press. Your lower body doesn’t look like it’s contributing much leg drive.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# The descent looks controlled overall. Your elbows appear reasonably tucked rather than excessively flared, which is a positive. From this front/angled view, I can’t clearly confirm the exact elbow angle throughout.
#
# 4. **Range of motion and completion**
# You are reaching the chest and pressing back to lockout, so the rep range looks complete. That said, the bar path and touch point are a little hard to judge from this camera angle. A side view would make it much easier to assess whether you’re pressing in a consistent path.
#
# If you want, I can also give you the top 3 fixes to improve your bench setup and leg drive right away.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpc2b22nqi/tmpl03ptj5y
# Video name: tmpl03ptj5y
# BEFORE VECTOR DB - classified_keywords: Bench press     Grip   hand position      Wrists   forearms alignment      Shoulder position  scapular set       Upper back   torso arch      Ribcage   breathing position      Elbow tracking  angle trajectory       Bar path line  relative to chest       Chest shoulder contact point      Lower body base  feet placement        Glutes hips contact with bench       Head   neck position       Lockout alignment  shoulders  elbows  bar height
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8884
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Nice work — this looks like a solid bench press rep overall. Here’s the breakdown:
#
# 1. **Setup and starting position**
# Your upper back, head, and glutes appear to stay planted on the bench, which is good. Your feet also look in contact with the floor throughout, which is important for staying tight. One thing I’d improve: your feet look a little far forward, which may limit leg drive. If comfortable, try bringing them slightly farther back so your shins are closer to vertical while keeping your butt down on the bench.
#
# 2. **Lifting phase (concentric) — the effort portion**
# The press looks controlled and fairly straight. You’re not wildly flaring the elbows, which is good for shoulder position. The rep comes up smoothly without any obvious loss of control. I’d cue you to keep gripping the bar hard and think about staying tight through the upper back as you press.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# The descent looks controlled, not like you’re dropping the bar. That’s a positive. Your elbows appear reasonably tucked rather than excessively flared. From this side angle, I can’t fully judge the exact elbow angle from the top view, so I wouldn’t want to guess beyond that.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# It looks like you’re touching the bar to the chest area and returning to a locked-out top position, so the range of motion looks complete. The rep appears finished properly at the top.
#
# One camera note: this side angle is decent for bar path and body contact points, but a front-diagonal angle would make it easier to judge grip width, elbow position, and symmetry.
#
# If you want, I can also give you **3 specific cues to make your bench stronger and more stable on your next set**.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpgpaf7kee/tmppllbuow7
# Video name: tmppllbuow7
# BEFORE VECTOR DB - classified_keywords: Bench press     Grip   hand position    Wrists alignment    Elbow position  angle     Shoulder position  scapula set     Upper back   lats engagement    Chest position    Ribcage   torso arch    Feet position   planted base    Glutes position     Head   neck position     Bar path over mid chest     Lockout   overhead extension alignment
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: The next thing I want to talk about is back position. As you lie down on the bench, you want to posi
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# AFTER VECTOR DB - top_k_chunks length: 8200
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: You’re looking solid overall — controlled reps, consistent touch point, and the bar gets back to lockout without any obvious loss of control.
#
# 1. Setup and starting position
# This mostly looks correct. Your head, upper back, glutes, and feet appear planted, which is great. Your eyes also look pretty close to under the bar. One thing I’d clean up: your feet don’t look set very far back, so you may be leaving some leg drive and full-body tightness on the table. If you can, bring your feet back as far as is comfortable while keeping your glutes on the bench, and keep driving your upper back into the bench.
#
# 2. Lifting phase (concentric) — the effort portion
# This looks good overall. You press the bar up with solid control and no major wobble. Your elbows appear reasonably positioned rather than flared excessively, which is a good sign for shoulder comfort. I’d just focus on squeezing the bar harder and keeping the upper back tight so the press stays even smoother.
#
# 3. Lowering phase (eccentric) — the controlled return
# This also looks good. You lower the bar under control to a consistent spot on your chest rather than letting it drift around. From this angle, your elbow position on the way down looks pretty close to the 45-degree range, which is what you want.
#
# 4. Range of motion and completion — did the rep finish at full range, top and bottom?
# Looks correct. You’re touching the chest and returning to a strong top position with elbows locked out. Range of motion appears complete on the reps shown.
#
# One camera note: this side angle is decent, but a slightly more direct side view lined up with the bar and shoulder would make wrist stacking and bar path easier to judge.
#
# If you want, I can also give you 3 specific cues to make your bench stronger right away.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmp_5pn51zf/tmp5ds7eplg
# Video name: tmp5ds7eplg
# BEFORE VECTOR DB - classified_keywords: Decline bench press     Bench contact points  upper back  glutes  head     Feet   base position    Scapula position  retraction depression     Upper back   posture    Elbow position   tracking    Shoulder position  glenohumeral alignment     Wrist alignment    Bar path   bar position relative to chest    Core   ribcage position     Head   neck alignment     Lockout position  bench press finish
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: While there are exceptions, doing squats for greater than 10 reps or so will usually cause your card
# CHUNK PREVIEW: they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum a
# AFTER VECTOR DB - top_k_chunks length: 9369
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Yes — overall this looks pretty solid, but I do see a few things to clean up on your bench press.
#
# 1. Setup and starting position
# Your grip width looks reasonable, and your feet are on the floor, which is good. One issue is that your upper back doesn’t look very tightly set and planted into the bench. You’d likely be more stable if you pinched your shoulder blades together and kept your chest up harder before you unrack. Your feet also look a bit passive rather than driving into the floor.
#
# 2. Lifting phase (concentric) — the effort portion
# The bar comes up successfully, but the press looks slightly uneven side to side, with one arm appearing to lock out a bit ahead of the other. That usually means you could benefit from more upper-back tightness and a stronger, more consistent leg drive. Try thinking about tightening your glutes and pushing through the floor as you press.
#
# 3. Lowering phase (eccentric) — the controlled return
# The descent looks controlled overall. I don’t see anything obviously reckless here. Your elbow angle also looks fairly reasonable rather than excessively flared.
#
# 4. Range of motion and completion — did the rep finish at full range, top and bottom?
# This is the main issue I notice: you are very close to your chest at the bottom, but it doesn’t clearly look like the bar is consistently touching your chest every rep. At the top, you appear to reach near lockout. For consistency and strength progress, make each rep touch the chest and return to full lockout.
#
# One more thing: the camera angle is a bit obstructed by the rack uprights, so it limits how clearly I can assess shoulder position and exact bar path. If you want, I can also tell you the top 3 cues I’d use to fix this immediately on your next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpzt_w_6sb/tmp5j1s6_w5
# Video name: tmp5j1s6_w5
# BEFORE VECTOR DB - classified_keywords: Bench press  barbell      Feet   base      Lower body alignment  legs knees       Glutes   pelvis position      Core bracing   ribcage position      Shoulder blades  retraction depression       Shoulder position  glenohumeral alignment       Elbow position   forearm angle      Wrist alignment      Bar path trajectory relative to chest       Head   neck position       Grip width   hand placement       Finish lockout alignment  arms shoulders        Range of motion  bar to chest and return
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9280
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: 1. **Setup and starting position**
# Overall this looks pretty solid. Your upper back stays on the bench and you’re maintaining a clear arch, which is good. Your glutes also appear to stay in contact with the bench. The main setup issue I notice is your foot position: your feet are not very far back, and from this angle it looks like you may be losing some leg drive potential. I’d want your feet set as far back as you can comfortably manage while keeping your butt down, with your heels firmly planted so you can drive through the floor harder. Also, this camera angle makes it hard to judge whether your eyes are directly under the bar at setup and whether your shoulder blades are fully pinned back.
#
# 2. **Lifting phase (concentric) — the effort portion**
# The press looks controlled and fairly even side to side. Good job keeping your body mostly stable instead of squirming on the bench. One thing to clean up: the bar path looks a little drifty forward and back rather than returning crisply to the same lockout position each rep. Think about pressing back to the same spot over your shoulder joints every time. Your shoulders also look like they may be coming a bit loose as you initiate the press off the chest, so really keep the upper back tight and chest high.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# This part looks decent. You are lowering under control rather than dropping the bar. The main thing I’d watch is elbow position. From this angle, it’s hard to confirm precisely, but your elbows appear a touch flared at points. I’d aim to lower with the elbows about 45 degrees relative to your torso so the forearms stay in a strong pressing position at the bottom.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# You appear to be touching the chest and pressing to a solid top position, so your range of motion looks complete. Lockout looks basically there on the reps shown. The only caution is consistency: make sure each rep touches the same spot on your chest and finishes at the same top position, because right now the path looks slightly variable from rep to rep.
#
# If you want, I can also give you the top 3 technique changes that would improve your bench the fastest.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpfxokuvn5/tmp4w6acwy6
# Video name: tmp4w6acwy6
# BEFORE VECTOR DB - classified_keywords: Bench press     Feet   base  foot placement  drive through feet     Legs   hips  hip position  glute contact with bench     Lower back   torso  arching positioning  ribcage set     Shoulder blades  scapular retraction depression     Shoulder position  glenohumeral joint position  shoulder angles     Elbows   forearms  elbow tracking  forearm vertical     Grip   wrist alignment  wrist neutrality  bar grip     Bar path  bar line from start to press     Head   neck  head position on bench      Rep depth   bottom position  bar to chest lowest point alignment      Lockout position  arm straightness  shoulder integrity at top
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8972
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: 1. **Setup and starting position**
# You’ve got some good things here: your upper back stays on the bench, you have a noticeable arch, and your glutes appear to stay in contact with the bench. The biggest setup issue is your lower body. Your feet are set very wide and look more “spread out” than planted for efficient leg drive. I’d want your feet pulled farther back if comfortable, heels planted, and legs closer to the bench so you can drive through the floor and reinforce your arch better. Also, this angle makes it a little hard to judge whether your eyes started directly under the bar.
#
# 2. **Lifting phase (concentric)**
# The press looks strong overall, and the bar does come back toward the rack side as you press, which is fine. I do see some unevenness side to side—your right arm appears to lock a little differently than your left at points. That can mean you’re losing tightness or pressing slightly asymmetrically. Focus on gripping the bar hard and driving evenly through both hands while tightening glutes and legs into the floor.
#
# 3. **Lowering phase (eccentric)**
# The descent looks controlled. Your elbows appear reasonably tucked rather than flared hard out, which is good. One thing to clean up is consistency of the bar path on the way down—it looks like the touch point may drift a bit, so keeping your gaze fixed and lowering to the same spot each rep would help.
#
# 4. **Range of motion and completion**
# You are reaching the chest at the bottom and getting to near full lockout at the top. Range of motion looks solid overall. I don’t see an obvious short rep here.
#
# Big picture: strong bench, but your biggest improvement would come from a tighter lower-body setup and more stable, even leg drive.
#
# If you want, I can also give you 3 specific cues to fix your foot position and leg drive on your next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmprrx90xcl/tmp3eqe4k39
# Video name: tmp3eqe4k39
# BEFORE VECTOR DB - classified_keywords: Bench press     Feet   base    Legs   hip position    Glutes   lower back contact    Core   ribcage position    Shoulder position  scapula set     Upper arm position    Elbow path    Forearms   wrist alignment    Bar trajectory     Head   neck position     Grip width   hand placement     Lowering control phase     Pressing lockout position
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8972
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Here’s my bench press breakdown:
#
# 1. **Setup and starting position**
# Mostly solid. Your head, upper back, and glutes look planted on the bench, and your feet appear to stay in contact with the floor, which is good. One thing to improve: your feet look a bit far forward, which can limit leg drive. Try bringing them farther back under you as much as you comfortably can while keeping your glutes down on the bench. That should help you stay tighter through the whole set.
#
# 2. **Lifting phase (concentric) — the effort portion**
# This looks pretty good overall. You press the bar up under control and return to a strong lockout. I do notice the bar path looks fairly vertical from this side view, but it would likely be stronger and more shoulder-friendly if you thought about pressing slightly back toward the rack as you rise, rather than only straight up.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# This phase looks controlled, which is a positive. Your elbows also appear reasonably tucked instead of flaring excessively, which is a good sign. The camera angle makes it hard to judge your exact elbow angle from the top view, so I wouldn’t want to guess beyond that.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# You appear to reach full lockout at the top. At the bottom, the bar looks very close to or touching your chest, so range of motion seems good. I don’t see any obvious short reps here.
#
# **Biggest priority fix:** bring your feet a little farther back and use more leg drive while keeping your butt on the bench. That will make you more stable and help the press feel stronger.
#
# If you want, I can also give you 3 simple cues to focus on for your next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpunrvhx9u/tmp7agvmll4
# Video name: tmp7agvmll4
# BEFORE VECTOR DB - classified_keywords: Bench press  barbell      Feet   base      Lower body  glutes  hamstrings       Pelvis position  posterior pelvic tilt       Lumbar spine  lower back contact       Upper back  scapular retraction depression       Shoulder position  scaps set  shoulder alignment       Bar to chest touchpoint      Elbow position  angle and tracking       Wrist alignment       Neck   head  chin position        Bar path  vertical line over shoulder        Full lockout position  arm extension  shoulder control
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: The next thing I want to talk about is back position. As you lie down on the bench, you want to posi
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# AFTER VECTOR DB - top_k_chunks length: 8363
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: You look solid overall — the reps are controlled, the bar touches your chest, and you return to a consistent top position. Here’s the breakdown:
#
# 1. Setup and starting position
# ...
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8835
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Strong lift overall — you’re moving serious weight, and a few things already look solid. Here’s the breakdown:
#
# 1. **Setup and starting position**
# Your upper back looks planted on the bench, and you’ve created a noticeable arch. Your glutes appear to stay in contact with the bench, which is good. The main issue is your lower-body setup: your feet are very wide and look a bit far out to the sides, which makes leg drive less efficient. I’d want your feet set flatter and more deliberately so you can push into the floor harder without losing tightness.
#
# 2. **Lifting phase (concentric) — the effort portion**
# This looks mostly good. You press the bar back toward lockout rather than straight up over the chest, which is what you want. I do see a little unevenness side to side during the press, especially as the weight gets moving, so focus on gripping the bar harder and driving both sides evenly.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# The descent looks controlled, not like you’re dropping the bar. Your elbows also appear reasonably tucked rather than excessively flared, which is a good sign for safer pressing.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# You appear to reach the chest and then return to a strong top position. Range of motion looks complete. From this angle, the exact touch point on the chest isn’t perfectly clear, but it does look like you’re getting full reps.
#
# One more thing: this camera angle is decent for a general check, but a side-angle video would make bar path, touch point, and elbow position much easier to judge precisely.
#
# If you want, I can also give you the top 3 technique fixes that would most improve your bench right away.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmp0q8ae8f5/tmpi8w8tuz7
# Video name: tmpi8w8tuz7
# BEFORE VECTOR DB - classified_keywords: Dumbbell Barbell overhead press  supine or bench supported      Feet   planted base    Lower body alignment  hips knees ankles     Glutes   hamstrings engagement    Lumbar spine position    Ribcage position  down stacked vs flared     Core bracing anti extension    Shoulder blades  retraction   depression     Elbow tracking  angle relative to torso     Wrist alignment  stacked under load      Bar dumbbell path  vertical line      Shoulder external rotation  upper arm positioning      Neck   head position
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9312
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Nice work — this bench press looks pretty solid overall. Here’s the breakdown:
#
# **1. Setup and starting position**
# Mostly correct. Your head, upper back, and glutes appear to stay in contact with the bench, which is good. Your feet are on the floor, but they look a bit far forward, which may limit leg drive. I’d try bringing your feet farther back as long as your heels can stay planted and your butt stays down on the bench.
#
# **2. Lifting phase (concentric) — the effort portion**
# Looks good. The bar comes up under control without obvious twisting or loss of balance. You’re not doing anything wild with the hips, which is great. I’d just focus on keeping the whole body tighter and driving through the floor to reinforce your chest position as you press.
#
# **3. Lowering phase (eccentric) — the controlled return**
# Looks controlled. Your elbows appear reasonably tucked rather than flared straight out, which is what you want. The descent doesn’t look rushed.
#
# **4. Range of motion and completion — did the rep finish at full range, top and bottom?**
# This looks mostly complete. You reach the chest at the bottom and return to a strong top position. Lockout looks close to full. From this side angle, grip width and exact elbow angle are a little harder to judge clearly.
#
# If you want, I can also give you 2–3 specific technique cues to improve your bench on the next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpc6l1i25g/tmpsj6_44_c
# Video name: tmpsj6_44_c
# BEFORE VECTOR DB - classified_keywords: Barbell bench press     Feet   base of support      Lower body legs tension      Glutes contact   hip position      Shoulder blades  retraction depression       Shoulder joint position  rotator cuff alignment       Upper back   ribcage position      Forearm vertical alignment      Elbow tracking path      Wrist position       Bar position relative to chest       Head   neck position       Full body bracing torso rigidity       Depth at the bottom position       Pressing arm lockout position
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: The next thing I want to talk about is back position. As you lie down on the bench, you want to posi
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# AFTER VECTOR DB - top_k_chunks length: 8363
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: You’re looking solid overall — the reps look controlled, consistent, and safe. Here’s the breakdown:
#
# 1. **Setup and starting position**
# Looks mostly correct. Your head, upper back, glutes, and feet appear planted, which is a good base. The main thing I’d clean up is your upper-back tightness: it looks like you could pin your shoulder blades together harder and use the bench more as a stable platform. Your feet are down, but they look a bit relaxed rather than set aggressively for leg drive.
#
# 2. **Lifting phase (concentric) — the effort portion**
# This looks pretty good. You press the bar back up under control without obvious wobbling. One thing to watch: as you drive off the chest, it looks like your shoulders may be wanting to rise a little instead of staying locked into the bench. Think about driving your upper back into the bench while your arms press.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# Also good overall. You lower the bar with control and bring it to a consistent touch point on the chest. Your elbows appear reasonably tucked rather than flared excessively, which is what you want.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# Looks correct. You’re touching the chest and returning to a strong top position with elbows near lockout. Range looks complete on the reps shown.
#
# One camera note: this angle is decent for checking bar path and elbow position, but a view from directly in front or directly from the side would make shoulder position and wrist stacking easier to judge.
#
# If you want, I can also give you 3 specific cues to make your bench stronger right away.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpwz22_zxz/tmpwfl7op6v
# Video name: tmpwfl7op6v
# BEFORE VECTOR DB - classified_keywords: Bench press  barbell      Grip   hand position    Wrist alignment    Forearm   elbow angle    Shoulder position  scapula set     Upper back   posture    Chest position at lockout    Elbow path track    Bar to chest contact position    Leg drive   foot placement     Lower body position  hips glutes on bench      Core bracing     Head   neck position     Lockout position  bar height   arm extension      Bar stability control throughout rep
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: While there are exceptions, doing squats for greater than 10 reps or so will usually cause your card
# CHUNK PREVIEW: they're going to create more inconsistent reps and often lead to bouncy reps with lots of momentum a
# AFTER VECTOR DB - top_k_chunks length: 9005
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: Yes — overall this looks pretty solid, but I do see a few things to clean up on your bench.
#
# 1. Setup and starting position
# Your setup looks mostly correct: head, upper back, glutes, and feet appear planted, and your grip width looks reasonable. One issue is that your upper back doesn’t look especially tight or “set” into the bench. Try squeezing your shoulder blades together harder and keeping your chest up before you unrack. That will give you a more stable pressing platform.
#
# 2. Lifting phase (concentric) — the effort portion
# You are getting the bar back up consistently, which is good. The main issue is the bar path looks a little uneven and slightly shaky, especially as you press away from the chest. Think about driving the bar up and slightly back rather than just straight forward. Also, use more leg drive by pushing your feet into the floor as the bar leaves your chest.
#
# 3. Lowering phase (eccentric) — the controlled return
# The descent appears controlled, which is good. Your elbows also don’t look excessively flared, which is a positive. I would still cue you to keep “bending the bar” on the way down so the elbows stay tucked and the lats stay engaged.
#
# 4. Range of motion and completion — did the rep finish at full range, top and bottom?
# Your bottom position looks good: the bar reaches the chest consistently. At the top, you’re very close to full lockout, but a few reps look just short of a clearly finished position. Make sure every rep reaches the same top position so you’re not accidentally shortening range of motion over time.
#
# One more thing: this camera angle is usable, but the rack upright blocks part of the bar path and your torso, so a clearer side angle would make it much easier to judge elbow position and bar path precisely.
#
# If you want, I can also give you 3 simple cues to improve your bench on your very next set.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmp1qzjy8px/tmp1klgmaf_
# Video name: tmp1klgmaf_
# BEFORE VECTOR DB - classified_keywords: Bench press  setup and press      Feet   base      Legs   glute engagement      Lower back  arch    pelvis position      Ribcage torso position      Shoulder blades  retraction depression       Shoulder alignment  front of shoulders       Elbow position   forearm angle      Wrist position   grip      Bar position relative to chest       Head   neck position
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 8884
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: You’ve got a solid base here — the lift looks controlled, and the bar path is pretty consistent rep to rep. Here’s the breakdown:
#
# 1. **Setup and starting position**
# Your upper back looks planted on the bench, and you’ve created a noticeable arch, which is good. Your glutes appear to stay in contact with the bench, also good. Biggest issue: your feet don’t look ideally set for strong leg drive. They’re planted, but they seem a bit far forward, which makes it harder to drive through the floor and reinforce your arch. I’d like to see your feet tucked back a bit more if you can do that while keeping your butt down.
#
# 2. **Lifting phase (concentric) — the effort portion**
# This part looks pretty good. You press the bar up under control without a major tilt or wobble. Your elbows also appear reasonably tucked rather than flaring excessively, which is a positive.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# The descent looks controlled overall. The bar comes down steadily to the chest area without crashing. From this angle, elbow position is a little hard to judge perfectly, but it does not look wildly flared.
#
# 4. **Range of motion and completion**
# You are touching the bar to your chest and pressing to a completed top position. Range of motion looks full on both the bottom and top.
#
# One more thing: this camera angle is decent for setup and leg position, but a more side-on angle at chest height would make bar path and elbow position easier to judge. If you want, I can also give you 2-3 specific cues to improve your leg drive on bench.
# Frames processed: 15, (10s cap)
# Saved to /var/folders/2n/c95ntf5d1wx1_vrd1b3ljbkw0000gn/T/tmpk94v8r8s/tmpg5a2_co5
# Video name: tmpg5a2_co5
# BEFORE VECTOR DB - classified_keywords: Bench press     Feet   base    Legs   knee alignment    Glutes   lower back position    Scapula position  retraction depression     Shoulder position  glenohumeral alignment     Upper arm angle   elbow tracking    Forearm   wrist alignment    Bar path over chest    Hand grip width   symmetry     Head   neck position     Chest contact point  if applicable      Lockout alignment  elbows shoulders
# RESULTS COUNT: 10
# UNIQUE RESULTS COUNT: 10
# CHUNK PREVIEW: Now, your back should be planted on the bench, with your eyes directly under the barbell. Position y
# CHUNK PREVIEW: along the bench through the hips into the arched back to reinforce the arch and keep the chest in it
# AFTER VECTOR DB - top_k_chunks length: 9280
# STATE KEYS: dict_keys(['user_query', 'session_id', 'classified_keywords', 'encoded_images', 'user_video', 'classification_image', 'top_k_chunks', 'response'])
# RESPONSE: 1. **Setup and starting position**
# Your upper back looks planted and you’ve got a noticeable arch, which is fine. The biggest setup issue is your lower body: your feet are very wide and look more like they’re just spread out than set for strong leg drive. I’d rather see your feet pulled farther back and flatter to the floor, with your legs closer to the bench. Also, make sure your glutes stay in contact with the bench the whole time. One more safety note: this is a heavy attempt and there’s no spotter visible.
#
# 2. **Lifting phase (concentric) — the effort portion**
# You do get the bar moving and finish the reps, but the press looks uneven side-to-side. Your left side appears to lag slightly, and the bar path isn’t perfectly steady. That usually means you’re losing tightness through the upper back or not driving evenly through the hands and feet. Think about gripping the bar harder and keeping your chest high while pressing back to the same lockout position each rep.
#
# 3. **Lowering phase (eccentric) — the controlled return**
# The descent is visible and generally controlled. Your elbows appear reasonably tucked rather than flared straight out, which is good. What’s less clear from this angle is whether the bar is staying stacked cleanly over your forearms the whole way down.
#
# 4. **Range of motion and completion — did the rep finish at full range, top and bottom?**
# You appear to touch the chest and return to a solid top position. Lockout looks basically complete. Bottom position reaches full depth for a bench rep.
#
# If you want, I can also give you the **top 3 fixes that would improve your bench the fastest**.

# %%
from langsmith import Client
from langsmith.evaluation import evaluate

langsmith_client = Client()

os.environ["LANGCHAIN_TRACING_V2"] = "false" 
# stops LangSmith from trying to log all the big intermediate data
# evaluate() function will still capture your inputs, outputs, and evaluator scores
# it just won't try to upload the full trace with all those heavy frames.
# 
results = evaluate(
    run_rag_pipeline,
    data="Image assessment response accuracy v1",
    evaluators=[correctness_evaluator, hallucination_evaluator],
    experiment_prefix="test43-system-prompt-scaffold-update",
)
